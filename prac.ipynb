# %%
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim
import numpy as np
import os

tokenizer = RegexpTokenizer(r'\w+')

# %%
# create English stop words list
en_stop = get_stop_words('en')

# %%
# Create p_stemmer of class PorterStemmer
p_stemmer = PorterStemmer()

# %%
paper_directory = "../2014/papers_text/"

#paper_array = names of all papers in dataset ordered lexically
paper_array = []
for filename in os.listdir(paper_directory):
    if filename.endswith(".txt"): 
        #print(os.path.join(directory, filename))
        paper_array.append(filename[:-4])
paper_array = sorted(paper_array)

filenames = [paper_directory + x + ".txt" for x in paper_array]
doc_list = [open(f).read() for f in filenames[:2]]

# %%
# list for tokenized documents in loop
texts = []

# loop through document list
for i in doc_list:
    
    # clean and tokenize document string
    raw = i.lower()
    tokens = tokenizer.tokenize(raw)
    

    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if not i in en_stop]
    
    # stem tokens
    stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
    
    # removing words of length < 3 (some integers were interfering in topics otherwise)
    filtered_tokens = [i for i in stemmed_tokens if len(i)>2]
    
    # add tokens to list
    texts.append(filtered_tokens)

# %%
texts[:5]
# Out:
# [['bustuc',
#   'natura',
#   u'anguag',
#   u'rout',
#   'rac',
#   'tore',
#   u'ambl',
#   'dept',
#   u'comput',
#   u'inform',
#   u'scienc',
#   u'univers',
#   'trondheim',
#   'norway',
#   '7491',
#   u'ambl',
#   'idi',
#   'ntnu',
#   'abstract',
#   'paper',
#   u'describ',
#   u'natur',
#   u'anguag',
#   u'base',
#   'expert',
#   'system',
#   u'rout',
#   'advisor',
#   'public',
#   'transport',
#   'trondheim',
#   'norway',
#   'system',
#   u'avail',
#   'internet',
#   u'intstal',
#   'com',
#   u'pani',
#   'web',
#   'server',
#   u'sinc',
#   u'begin',
#   '1999',
#   'system',
#   u'bilingu',
#   u'reli',
#   u'intern',
#   u'anguag',
#   u'independ',
#   'logic',
#   u'represent',
#   'introduct',
#   'ion',
#   u'natur',
#   u'anguag',
#   u'interfac',
#   u'comput',
#   u'databas',
#   u'provid',
#   u'user',
#   u'capabl',
#   u'obtain',
#   u'format',
#   u'store',
#   u'databas',
#   u'queri',
#   'system',
#   u'natur',
#   u'languag',
#   u'natur',
#   u'languag',
#   u'mean',
#   u'commun',
#   'com',
#   'puter',
#   'system',
#   u'user',
#   'can',
#   'make',
#   'question',
#   'statement',
#   'way',
#   u'normal',
#   'think',
#   u'inform',
#   u'discuss',
#   u'free',
#   'hav',
#   'ing',
#   'know',
#   u'comput',
#   u'store',
#   u'process',
#   u'inform',
#   'present',
#   u'implement',
#   u'repres',
#   'major',
#   'effort',
#   u'bring',
#   u'natur',
#   u'anguag',
#   u'practic',
#   'use',
#   'system',
#   u'develop',
#   'can',
#   'answer',
#   u'queri',
#   u'rout',
#   u'state',
#   u'natur',
#   u'languag',
#   u'text',
#   'made',
#   'public',
#   'internet',
#   'world',
#   'wide',
#   'web',
#   'http',
#   'www',
#   'idi',
#   'ntnu',
#   'bustuc',
#   'trondheim',
#   'small',
#   u'citi',
#   u'univers',
#   '140000',
#   u'inhabit',
#   'central',
#   u'system',
#   u'line',
#   u'serv',
#   '590',
#   u'station',
#   '1900',
#   'depar',
#   u'ture',
#   'per',
#   'day',
#   u'averag',
#   u'give',
#   u'approxim',
#   '60000',
#   u'schedul',
#   'station',
#   u'pass',
#   'per',
#   'day',
#   'somehow',
#   u'repres',
#   u'rout',
#   'data',
#   'base',
#   u'start',
#   'point',
#   u'autom',
#   'function',
#   u'rout',
#   u'inform',
#   'agent',
#   u'follow',
#   u'exampl',
#   'system',
#   u'respons',
#   u'use',
#   'actual',
#   'request',
#   u'telephon',
#   'local',
#   u'rout',
#   u'inform',
#   u'compani',
#   'live',
#   u'nidarvol',
#   'tonight',
#   'must',
#   'reach',
#   'train',
#   'oslo',
#   'oclock',
#   u'typic',
#   'answer',
#   'follow',
#   u'quickli',
#   'number',
#   u'pass',
#   u'nidarvol',
#   'skole',
#   '1710',
#   u'arriv',
#   'trondheim',
#   'railway',
#   'station',
#   '1725',
#   'question',
#   'answer',
#   'pro',
#   u'cess',
#   u'lexic',
#   u'analysi',
#   'syntax',
#   u'analysi',
#   u'semant',
#   u'analysi',
#   u'pragmat',
#   u'reason',
#   u'databas',
#   u'queri',
#   u'process',
#   'one',
#   u'argu',
#   u'inform',
#   'content',
#   u'solv',
#   u'interrog',
#   u'wherebi',
#   u'custom',
#   u'ask',
#   u'produc',
#   u'item',
#   'ion',
#   u'departur',
#   'station',
#   u'arriv',
#   'earliest',
#   u'departur',
#   'timeand',
#   'latest',
#   u'arriv',
#   'time',
#   'myth',
#   u'natur',
#   u'languag',
#   'better',
#   'way',
#   u'commun',
#   u'natur',
#   u'languag',
#   u'challeng',
#   'prove',
#   u'demonstr',
#   'system',
#   'can',
#   'made',
#   'will',
#   u'prefer',
#   u'interrog',
#   'mode',
#   'system',
#   'correct',
#   'user',
#   u'friendli',
#   'almost',
#   u'complet',
#   'within',
#   'actual',
#   'domain',
#   u'previou',
#   u'effort',
#   'chat',
#   'prat',
#   'hsql',
#   'system',
#   u'call',
#   'bustuc',
#   'built',
#   'upon',
#   u'cla',
#   'sical',
#   'system',
#   'chat',
#   'warren',
#   'pereira',
#   '1982',
#   'chat',
#   'state',
#   'art',
#   u'natur',
#   u'anguag',
#   'tem',
#   u'impress',
#   u'merit',
#   'also',
#   u'establish',
#   'prolog',
#   u'viabl',
#   u'competit',
#   'lan',
#   u'guag',
#   u'artifici',
#   u'intellig',
#   u'gener',
#   'tem',
#   'brilliant',
#   u'masterpiec',
#   u'softwar',
#   u'effici',
#   u'sophist',
#   u'natur',
#   u'anguag',
#   'system',
#   u'connect',
#   'small',
#   u'queri',
#   'system',
#   u'intern',
#   u'geographi',
#   u'follow',
#   u'queri',
#   u'analys',
#   u'answer',
#   'split',
#   'second',
#   u'countri',
#   u'border',
#   'mediterranean',
#   u'border',
#   u'countri',
#   u'border',
#   u'countri',
#   'whose',
#   u'popul',
#   u'exce',
#   u'popul',
#   'india',
#   'answer',
#   'turkey',
#   u'becom',
#   'incorrect',
#   'time',
#   u'pass',
#   u'ironi',
#   u'geographi',
#   'chosen',
#   'domain',
#   'without',
#   'time',
#   'abi',
#   u'iti',
#   'answer',
#   u'ridicul',
#   'long',
#   u'queri',
#   u'cours',
#   'main',
#   'goal',
#   'main',
#   'lesson',
#   'complex',
#   u'sentenc',
#   u'analys',
#   'proper',
#   u'stand',
#   'without',
#   u'sacrif',
#   u'effici',
#   'superfi',
#   'cial',
#   'pattern',
#   u'match',
#   u'techniqu',
#   'prove',
#   u'futil',
#   'sooner',
#   'later',
#   u'make',
#   'norwegian',
#   'chat',
#   'prat',
#   u'univers',
#   'trondheim',
#   'ntnu',
#   'two',
#   'stu',
#   u'dent',
#   'made',
#   'norwegian',
#   'version',
#   'chat',
#   u'call',
#   'prat',
#   'teigen',
#   'vetland',
#   '1988',
#   'teigen',
#   'vetland',
#   '1989',
#   'also',
#   'similar',
#   'swedish',
#   'project',
#   'snack',
#   u'report',
#   u'dictionari',
#   u'chang',
#   'english',
#   'wegian',
#   u'togeth',
#   'new',
#   u'rule',
#   u'morpholog',
#   u'analysi',
#   u'chang',
#   'grammar',
#   'english',
#   'norwegian',
#   u'prove',
#   u'amazingli',
#   u'easi',
#   u'show',
#   u'langaug',
#   'similar',
#   'one',
#   u'believ',
#   'given',
#   u'languag',
#   'incomprehen',
#   u'sibl',
#   u'commun',
#   u'chang',
#   u'dictionari',
#   'graramar',
#   u'follow',
#   'norwegian',
#   u'queri',
#   'domain',
#   u'answer',
#   u'correctli',
#   u'second',
#   u'hvilk',
#   u'afrikansk',
#   'land',
#   'som',
#   'hat',
#   u'befolkn',
#   u'stoerr',
#   'enn',
#   u'million',
#   u'mindr',
#   'enn',
#   u'million',
#   'nord',
#   'botswana',
#   'oest',
#   'libya',
#   'hat',
#   'hovedstad',
#   'som',
#   'hat',
#   u'befolkn',
#   u'stoerr',
#   'enn',
#   '100',
#   'tusen',
#   u'translat',
#   u'besid',
#   'point',
#   'long',
#   u'queri',
#   'norwegian',
#   'hsql',
#   'help',
#   'system',
#   'sql',
#   'nordic',
#   'project',
#   'hsql',
#   'help',
#   'system',
#   'sql',
#   u'accomplish',
#   '1988',
#   'make',
#   'joint',
#   'nordic',
#   'fort',
#   u'interfac',
#   u'databas',
#   'hsql',
#   'project',
#   'led',
#   'swedish',
#   'state',
#   'bureau',
#   'statskontoret',
#   u'particip',
#   'swe',
#   'den',
#   'denmark',
#   'finland',
#   'norway',
#   u'ambl',
#   '1990',
#   'aim',
#   'hsql',
#   'build',
#   u'natur',
#   u'languag',
#   u'interfac',
#   'sql',
#   u'databas',
#   'scandi',
#   'navian',
#   u'languag',
#   'swedish',
#   'danish',
#   'norwegian',
#   u'languag',
#   'similar',
#   u'norw',
#   'gian',
#   'version',
#   'chat',
#   u'easili',
#   u'extend',
#   'scandinavian',
#   u'languag',
#   'instead',
#   'geogra',
#   u'phi',
#   u'typic',
#   u'applic',
#   'area',
#   'chosen',
#   u'queri',
#   'system',
#   u'hospit',
#   u'administr',
#   u'decid',
#   'target',
#   'sql',
#   u'databas',
#   u'hospit',
#   u'ministr',
#   u'develop',
#   u'alreadi',
#   'next',
#   'step',
#   u'chang',
#   'domain',
#   u'discours',
#   u'geographi',
#   u'hospit',
#   u'admini',
#   'tration',
#   u'use',
#   u'knowledg',
#   u'represent',
#   u'techniqu',
#   u'use',
#   'chat',
#   u'semant',
#   'model',
#   'domain',
#   'made',
#   u'implement',
#   'chat',
#   'framework',
#   u'model',
#   u'techniqu',
#   u'prove',
#   u'adequ',
#   'use',
#   u'extend',
#   u'entiti',
#   'relationship',
#   'model',
#   u'class',
#   'type',
#   u'hierarchi',
#   u'attribut',
#   u'long',
#   u'class',
#   u'singl',
#   u'inherit',
#   u'ofattribut',
#   u'relationship',
#   u'coupl',
#   'system',
#   'sql',
#   u'databas',
#   u'remodel',
#   'system',
#   'answer',
#   u'queri',
#   'scandinavian',
#   u'intern',
#   u'hospit',
#   u'databas',
#   'well',
#   'chat',
#   'answer',
#   'geog',
#   u'raphi',
#   u'question',
#   'hsql',
#   u'produc',
#   'prolog',
#   'like',
#   'code',
#   'fol',
#   'first',
#   'order',
#   'logic',
#   u'execut',
#   u'map',
#   'fol',
#   'data',
#   'base',
#   'schema',
#   u'defin',
#   u'translat',
#   'fol',
#   'sql',
#   u'implement',
#   u'exampl',
#   u'hvilk',
#   'menn',
#   'ligger',
#   u'kvinn',
#   'seng',
#   'men',
#   'lie',
#   'woman',
#   'bed',
#   u'translat',
#   u'ryli',
#   'sql',
#   u'queri',
#   'select',
#   'distinct',
#   'name',
#   'sex',
#   'reg_no',
#   'sex',
#   'reg_no',
#   'bed_no',
#   'hosp_no',
#   'ward_no',
#   'patient',
#   u'occup',
#   'patient',
#   u'occup',
#   'ward',
#   'sex',
#   'reg_no',
#   'reg_no',
#   'sex',
#   'reg_no',
#   'reg_no',
#   'bed_no',
#   'bed_no',
#   'hosp_no',
#   'hosp_no',
#   'ward_no',
#   'ward_no',
#   u'understand',
#   u'comput',
#   'hsql',
#   u'valuabl',
#   u'xperienc',
#   'effort',
#   'make',
#   u'transport',
#   u'natur',
#   u'anguag',
#   u'interfac',
#   u'howev',
#   u'underli',
#   'system',
#   'chat',
#   u'restrict',
#   u'develop',
#   'hsql',
#   'project',
#   u'finish',
#   'inter',
#   'nal',
#   'reseach',
#   'project',
#   'tuc',
#   u'understand',
#   'com',
#   'puter',
#   u'initi',
#   'ntnu',
#   u'carri',
#   u'result',
#   'hsql',
#   'project',
#   u'goal',
#   u'differ',
#   'hsql',
#   'number',
#   u'way',
#   'con',
#   u'cern',
#   'multimedia',
#   u'interfac',
#   'hand',
#   u'portabl',
#   u'versatil',
#   'made',
#   'central',
#   u'issu',
#   u'concern',
#   u'gener',
#   u'languag',
#   u'applic',
#   'research',
#   u'goal',
#   'sum',
#   u'maris',
#   'give',
#   u'comput',
#   u'oper',
#   u'understand',
#   u'natur',
#   u'languag',
#   'build',
#   u'intellig',
#   u'system',
#   u'natur',
#   u'languag',
#   u'capabl',
#   u'studi',
#   'common',
#   u'sens',
#   u'reason',
#   u'natur',
#   u'guag',
#   'test',
#   'criterion',
#   u'understand',
#   u'capac',
#   'set',
#   u'definit',
#   u'natur',
#   'read',
#   u'abl',
#   'logic',
#   'nrl',
#   'system',
#   'answer',
#   u'queri',
#   'nrl',
#   'conform',
#   u'answer',
#   u'idealis',
#   u'ration',
#   'agent',
#   u'everi',
#   'man',
#   u'live',
#   u'love',
#   u'mari',
#   'john',
#   'man',
#   'john',
#   u'live',
#   u'love',
#   u'mari',
#   'john',
#   'nrl',
#   u'defin',
#   u'close',
#   'context',
#   u'thu',
#   u'terfac',
#   u'system',
#   u'principl',
#   u'defin',
#   u'simul',
#   u'environ',
#   u'dialogu',
#   'partner',
#   'tuc',
#   u'prototyp',
#   u'natur',
#   u'languag',
#   u'proce',
#   'sor',
#   'english',
#   'written',
#   'prolog',
#   u'design',
#   u'gener',
#   u'purpos',
#   u'easili',
#   u'adapt',
#   u'natur',
#   'lan',
#   u'guag',
#   'processor',
#   u'consist',
#   u'gener',
#   'grammar',
#   'subset',
#   'english',
#   u'semant',
#   u'knowledg',
#   'base',
#   u'modul',
#   u'interfac',
#   u'interfac',
#   'like',
#   'unix',
#   'sql',
#   u'databas',
#   u'gener',
#   'textual',
#   'informa',
#   'tion',
#   u'sourc',
#   'tabor',
#   'project',
#   u'happen',
#   u'universt',
#   'project',
#   'start',
#   u'ede',
#   '1996',
#   u'call',
#   'tabor',
#   'speech',
#   u'base',
#   'user',
#   u'interfac',
#   u'reason',
#   u'system',
#   'aim',
#   u'build',
#   u'automat',
#   'public',
#   'transport',
#   u'rout',
#   u'oracl',
#   u'avail',
#   'public',
#   u'telephon',
#   'onset',
#   'project',
#   'world',
#   'wide',
#   'web',
#   'fresh',
#   'widespread',
#   'today',
#   u'telephon',
#   'still',
#   u'regard',
#   'main',
#   u'sourc',
#   u'inform',
#   'public',
#   u'sinc',
#   'internet',
#   u'becam',
#   u'domin',
#   'medium',
#   'likeley',
#   'find',
#   u'comput',
#   'internet',
#   u'connect',
#   'find',
#   'local',
#   u'busrout',
#   u'tabl',
#   u'consequt',
#   'wide',
#   u'spread',
#   'cellular',
#   u'phone',
#   u'chang',
#   u'pictur',
#   'favour',
#   u'telephon',
#   u'anoth',
#   u'stori',
#   u'decid',
#   'text',
#   u'base',
#   u'inform',
#   'tem',
#   'built',
#   u'regardless',
#   u'statu',
#   'speech',
#   u'rocgnit',
#   'speech',
#   u'synthesi',
#   'effort',
#   u'prove',
#   'lag',
#   'behind',
#   'bustuc',
#   'system',
#   u'result',
#   'system',
#   'bustuc',
#   'grew',
#   u'natur',
#   u'applic',
#   'tuc',
#   'english',
#   u'prototyp',
#   'built',
#   'within',
#   u'month',
#   'bratseth',
#   '1997',
#   u'sinc',
#   'summer',
#   '1996',
#   u'prototyp',
#   'put',
#   'onto',
#   'internet',
#   u'develop',
#   u'test',
#   u'less',
#   u'continu',
#   'today',
#   'portant',
#   u'extens',
#   'system',
#   'made',
#   u'bilingu',
#   'norwegian',
#   'english',
#   'fall',
#   '1996',
#   'spring',
#   '1999',
#   'bustuc',
#   u'final',
#   u'adopt',
#   'local',
#   u'compani',
#   'trondheim',
#   'trondheim',
#   'trafikkselskap',
#   'set',
#   'server',
#   '300',
#   'mhz',
#   'linux',
#   'today',
#   '150',
#   '000',
#   u'question',
#   u'swere',
#   'bustuc',
#   u'seem',
#   u'stabil',
#   'grow',
#   u'increasingli',
#   'popular',
#   u'anatomi',
#   u'rout',
#   'orac',
#   'main',
#   u'compon',
#   u'rout',
#   u'inform',
#   u'system',
#   'parser',
#   'system',
#   u'consist',
#   u'dictionari',
#   u'lexic',
#   'processor',
#   'grammar',
#   'parser',
#   u'knowledg',
#   'base',
#   u'divid',
#   u'semant',
#   u'applic',
#   u'queri',
#   'processor',
#   'contalng',
#   u'rout',
#   'logic',
#   'tem',
#   u'rout',
#   'data',
#   'base',
#   'system',
#   u'bilingu',
#   u'contain',
#   u'doubl',
#   'set',
#   u'dictionari',
#   u'morpholog',
#   'grammar',
#   ...],
#  [u'machin',
#   u'translat',
#   'close',
#   u'languag',
#   'jan',
#   'haji',
#   u'comput',
#   u'scienc',
#   'dept',
#   u'john',
#   u'hopkin',
#   u'univers',
#   '3400',
#   u'charl',
#   u'baltimor',
#   '21218',
#   'usa',
#   'hajic',
#   'jhu',
#   'edu',
#   'jan',
#   'hric',
#   'kti',
#   'mff',
#   'malostransk6',
#   'nfim',
#   'praha',
#   'czech',
#   u'republ',
#   '11800',
#   'hric',
#   'barbora',
#   'cuni',
#   'vladislav',
#   'kubon',
#   'ofal',
#   'mff',
#   'malostransk6',
#   'mim',
#   'praha',
#   'czech',
#   u'republ',
#   '11800',
#   'ufal',
#   'mff',
#   'cuni',
#   'abstract',
#   u'use',
#   u'exampl',
#   'transfer',
#   u'base',
#   'system',
#   'czech',
#   'russian',
#   'ruslan',
#   'word',
#   'word',
#   'system',
#   u'morpholog',
#   u'disambigu',
#   'czech',
#   'slovak',
#   'esilko',
#   u'argu',
#   u'realli',
#   'close',
#   u'languag',
#   u'possibl',
#   'obtain',
#   'better',
#   u'translat',
#   u'qualiti',
#   u'mean',
#   'simpler',
#   u'method',
#   'problem',
#   u'translat',
#   'group',
#   u'typolog',
#   'similar',
#   u'languag',
#   u'use',
#   'pivot',
#   u'languag',
#   'also',
#   u'discuss',
#   u'introduct',
#   'although',
#   'field',
#   u'machin',
#   u'translat',
#   'long',
#   u'histori',
#   'number',
#   u'realli',
#   u'success',
#   u'system',
#   u'impress',
#   u'fund',
#   u'invest',
#   u'develop',
#   u'variou',
#   u'system',
#   u'wast',
#   u'stimul',
#   u'develop',
#   u'techniqu',
#   'allow',
#   u'translat',
#   'least',
#   u'technic',
#   u'text',
#   'certain',
#   u'limit',
#   'domain',
#   u'cours',
#   u'except',
#   u'demonstr',
#   'certain',
#   u'condit',
#   u'possibl',
#   'develop',
#   'system',
#   'will',
#   'save',
#   'money',
#   u'effort',
#   u'invest',
#   'human',
#   u'translat',
#   'main',
#   'reason',
#   'field',
#   'met',
#   u'expect',
#   'sci',
#   u'literatur',
#   'also',
#   u'expect',
#   u'scientif',
#   u'commun',
#   u'complex',
#   'task',
#   u'success',
#   u'automat',
#   u'translat',
#   'system',
#   u'requir',
#   u'applic',
#   u'techniqu',
#   u'sever',
#   u'area',
#   u'comput',
#   u'inguist',
#   u'morpholog',
#   'syntax',
#   u'semant',
#   u'discours',
#   u'analysi',
#   'etc',
#   u'necessari',
#   u'suffici',
#   u'condit',
#   u'gener',
#   'opinion',
#   'easier',
#   u'creat',
#   'system',
#   'pair',
#   u'relat',
#   u'languag',
#   u'contribut',
#   'like',
#   u'demonstr',
#   'hat',
#   u'assumpt',
#   u'hold',
#   u'realli',
#   u'close',
#   u'relat',
#   u'languag',
#   'czech',
#   'russian',
#   'system',
#   'ruslan',
#   u'histori',
#   'first',
#   'attempt',
#   u'verifi',
#   u'hypothesi',
#   u'relat',
#   u'languag',
#   'easier',
#   u'translat',
#   u'start',
#   'mid',
#   u'charl',
#   u'univers',
#   u'pragu',
#   'project',
#   u'call',
#   'ruslan',
#   u'aim',
#   u'translat',
#   u'document',
#   'domain',
#   u'oper',
#   u'system',
#   u'mainfram',
#   u'comput',
#   u'develop',
#   u'cooper',
#   'research',
#   u'institut',
#   u'mathemat',
#   u'machin',
#   u'pragu',
#   'time',
#   'former',
#   'comecon',
#   u'countri',
#   u'obligatori',
#   u'translat',
#   'kind',
#   u'document',
#   u'system',
#   'russian',
#   'work',
#   'czech',
#   'russian',
#   'system',
#   'ruslan',
#   'oliva',
#   '1989',
#   u'start',
#   '1985',
#   u'termin',
#   '1990',
#   'comecon',
#   'gone',
#   'lack',
#   u'fund',
#   'system',
#   u'descript',
#   'system',
#   'rule',
#   u'base',
#   u'implement',
#   u'colmerau',
#   u'system',
#   u'contain',
#   'full',
#   u'fledg',
#   u'morpholog',
#   u'syntact',
#   u'analysi',
#   'czech',
#   'transfer',
#   u'syntact',
#   u'morpholog',
#   u'gener',
#   'russian',
#   'almost',
#   'transfer',
#   u'begin',
#   'project',
#   'due',
#   u'assumpt',
#   u'languag',
#   'similar',
#   'extent',
#   u'requir',
#   'transfer',
#   'phase',
#   u'assumpt',
#   u'turn',
#   'wrong',
#   u'sever',
#   'phenomena',
#   u'cover',
#   'transfer',
#   'later',
#   'stage',
#   'project',
#   u'exampl',
#   u'translat',
#   'czech',
#   'verb',
#   'one',
#   'three',
#   u'possibl',
#   'russian',
#   u'equival',
#   u'empti',
#   'form',
#   'form',
#   'byt6',
#   u'futur',
#   u'tens',
#   'verb',
#   'javljat6sja',
#   u'translat',
#   'verbal',
#   u'negat',
#   'time',
#   'work',
#   u'termin',
#   '1990',
#   'system',
#   'main',
#   u'translat',
#   u'dictionari',
#   '8000',
#   u'word',
#   u'accompani',
#   u'call',
#   u'transduc',
#   u'dictionari',
#   u'cover',
#   u'anoth',
#   '2000',
#   u'word',
#   u'transduc',
#   u'dictionari',
#   u'base',
#   u'origin',
#   'idea',
#   u'describ',
#   'kirschner',
#   '1987',
#   u'aim',
#   u'exploit',
#   'fact',
#   u'technic',
#   u'term',
#   u'base',
#   u'major',
#   'european',
#   u'languag',
#   'greek',
#   'latin',
#   u'stem',
#   u'adopt',
#   u'accord',
#   'particular',
#   u'deriv',
#   u'rule',
#   'given',
#   u'languag',
#   'fact',
#   u'allow',
#   u'translat',
#   u'technic',
#   u'term',
#   u'mean',
#   'direct',
#   u'transcript',
#   u'product',
#   u'nding',
#   'slight',
#   'regular',
#   u'adjust',
#   u'spell',
#   'stem',
#   u'exampl',
#   'english',
#   u'word',
#   u'local',
#   u'discrimin',
#   'can',
#   u'transcrib',
#   'czech',
#   u'lokalizac',
#   u'diskriminac',
#   u'product',
#   'nding',
#   'ation',
#   u'transcrib',
#   'ace',
#   u'gener',
#   u'assum',
#   'pair',
#   'czech',
#   'russian',
#   u'transduc',
#   u'dictionari',
#   u'abl',
#   'profit',
#   u'substanti',
#   'greater',
#   'number',
#   u'product',
#   u'rule',
#   u'hypothesi',
#   u'prove',
#   'wrong',
#   'see',
#   'b6mov',
#   'kubofi',
#   '1990',
#   'set',
#   u'product',
#   u'nding',
#   u'pair',
#   'english',
#   'czech',
#   u'develop',
#   'earlier',
#   'system',
#   'english',
#   'czech',
#   'czech',
#   'russian',
#   'similar',
#   u'evalu',
#   u'result',
#   'ruslan',
#   u'show',
#   u'roughli',
#   'input',
#   u'sentenc',
#   u'translat',
#   u'correctli',
#   'minor',
#   u'error',
#   u'correct',
#   'human',
#   'post',
#   'editor',
#   'input',
#   u'requir',
#   u'substanti',
#   u'edit',
#   u'translat',
#   'two',
#   'main',
#   u'factor',
#   u'caus',
#   u'deterior',
#   u'translat',
#   'first',
#   'factor',
#   u'incomplet',
#   'main',
#   u'dictionari',
#   'system',
#   'even',
#   'though',
#   'system',
#   u'contain',
#   'set',
#   u'call',
#   'fail',
#   'soft',
#   u'rule',
#   'whose',
#   'task',
#   u'handl',
#   u'situat',
#   'unknown',
#   'word',
#   u'typic',
#   u'caus',
#   u'failur',
#   u'modul',
#   u'syntact',
#   u'analysi',
#   u'dictionari',
#   u'entri',
#   u'contain',
#   u'besid',
#   u'translat',
#   u'equival',
#   u'morpholog',
#   u'inform',
#   u'import',
#   u'syntact',
#   u'inform',
#   'second',
#   'factor',
#   u'modul',
#   u'syntact',
#   u'analysi',
#   'czech',
#   u'sever',
#   u'reason',
#   u'pars',
#   u'failur',
#   'apart',
#   'common',
#   u'inabl',
#   'rule',
#   u'base',
#   'formal',
#   u'grammar',
#   'cover',
#   'particular',
#   u'natur',
#   u'anguag',
#   'finest',
#   'detail',
#   'syntax',
#   u'problem',
#   'one',
#   u'exist',
#   'non',
#   u'project',
#   u'construct',
#   u'quit',
#   'common',
#   'czech',
#   'even',
#   u'rel',
#   'short',
#   u'sentenc',
#   'even',
#   'though',
#   'account',
#   u'syntact',
#   u'depend',
#   u'everi',
#   'third',
#   'czech',
#   u'sentenc',
#   u'contain',
#   'least',
#   'one',
#   u'news',
#   u'corpu',
#   u'discov',
#   'much',
#   'non',
#   u'project',
#   u'depend',
#   'see',
#   'also',
#   'haji6',
#   '1998',
#   u'exampl',
#   'non',
#   u'project',
#   u'construct',
#   'soubor',
#   'nepodafilo',
#   'otev',
#   'lit',
#   'file',
#   'refl',
#   'was_not',
#   u'_possibl',
#   'to_open',
#   u'possibl',
#   'open',
#   'file',
#   u'formal',
#   u'use',
#   u'implement',
#   u'system',
#   'meant',
#   u'handl',
#   'non',
#   u'project',
#   u'construct',
#   u'anoth',
#   u'sourc',
#   u'troubl',
#   'use',
#   u'call',
#   u'semant',
#   u'featur',
#   u'featur',
#   u'base',
#   u'lexic',
#   u'semant',
#   u'individu',
#   u'word',
#   'main',
#   'task',
#   'support',
#   u'semant',
#   u'plausibl',
#   u'analysi',
#   'block',
#   u'implaus',
#   u'one',
#   u'turn',
#   'question',
#   u'implaus',
#   u'combin',
#   u'semant',
#   u'featur',
#   'also',
#   'complex',
#   u'suppos',
#   u'practic',
#   u'outcom',
#   'use',
#   u'semant',
#   u'featur',
#   'higher',
#   'atio',
#   u'pars',
#   u'failur',
#   u'semant',
#   u'featur',
#   'often',
#   u'block',
#   u'plausibl',
#   u'analysi',
#   u'exampl',
#   'human',
#   u'lexicograph',
#   u'sign',
#   'verb',
#   'run',
#   u'semant',
#   u'featur',
#   u'state',
#   'noun',
#   u'semant',
#   u'featur',
#   'human',
#   u'live',
#   'may',
#   u'assign',
#   'role',
#   'subject',
#   'verb',
#   'input',
#   'text',
#   u'howev',
#   'full',
#   u'sentenc',
#   u'program',
#   u'system',
#   u'run',
#   'etc',
#   u'cours',
#   u'easi',
#   'correct',
#   u'semant',
#   u'featur',
#   u'dictionari',
#   'problem',
#   'far',
#   u'mani',
#   u'correct',
#   u'requir',
#   'hand',
#   'fact',
#   u'languag',
#   'allow',
#   'high',
#   u'degre',
#   'word',
#   'order',
#   'freedom',
#   u'account',
#   'certain',
#   u'simplif',
#   u'translat',
#   u'process',
#   'grammar',
#   u'eli',
#   'fact',
#   'minor',
#   'word',
#   'order',
#   u'differ',
#   'czech',
#   'russian',
#   u'lesson',
#   u'learn',
#   'rom',
#   'ruslan',
#   u'learn',
#   u'sever',
#   u'lesson',
#   u'regard',
#   u'close',
#   u'relat',
#   u'languag',
#   'transfer',
#   u'base',
#   'approach',
#   u'provid',
#   'similar',
#   u'qualiti',
#   u'translat',
#   u'close',
#   u'relat',
#   u'typolog',
#   u'differ',
#   u'languag',
#   'two',
#   'main',
#   u'bottleneck',
#   'full',
#   u'fledg',
#   'transfer',
#   u'base',
#   u'system',
#   u'complex',
#   u'syntact',
#   u'dictionari',
#   u'rel',
#   u'unreli',
#   u'syntact',
#   u'analysi',
#   u'sourc',
#   u'languag',
#   'even',
#   u'rel',
#   u'simpl',
#   u'compon',
#   u'transduc',
#   u'dictionari',
#   u'equal',
#   'complex',
#   'english',
#   'czech',
#   'czech',
#   'russian',
#   u'translat',
#   u'limit',
#   'text',
#   u'domain',
#   'exist',
#   'real',
#   'life',
#   u'necessari',
#   'work',
#   'high',
#   u'coverag',
#   u'dictionari',
#   'least',
#   u'sourc',
#   u'languag',
#   u'translat',
#   u'local',
#   'pivot',
#   u'languag',
#   u'local',
#   u'product',
#   u'document',
#   'great',
#   'problem',
#   u'compani',
#   u'want',
#   'strengthen',
#   u'posit',
#   'foreign',
#   u'languag',
#   'market',
#   u'especi',
#   u'compani',
#   u'produc',
#   u'variou',
#   u'kind',
#   u'softwar',
#   u'amount',
#   u'text',
#   u'local',
#   'huge',
#   u'local',
#   u'cost',
#   'huge',
#   'well',
#   u'quit',
#   'clear',
#   u'local',
#   'one',
#   u'sourc',
#   u'languag',
#   u'sever',
#   'target',
#   u'languag',
#   u'typolog',
#   'similar',
#   u'differ',
#   u'sourc',
#   u'languag',
#   u'wast',
#   'money',
#   'effort',
#   u'cours',
#   'much',
#   'easier',
#   u'translat',
#   u'text',
#   'czech',
#   'polish',
#   'russian',
#   'bulgarian',
#   'english',
#   'german',
#   u'languag',
#   u'sever',
#   u'reason',
#   u'local',
#   u'translat',
#   u'perform',
#   'pivot',
#   u'languag',
#   u'repres',
#   'certain',
#   'group',
#   u'close',
#   u'relat',
#   u'languag',
#   'apart',
#   u'polit',
#   u'reason',
#   u'translat',
#   'pivot',
#   u'languag',
#   u'sever',
#   u'drawback',
#   u'import',
#   'one',
#   'problem',
#   u'loss',
#   u'translat',
#   u'qualiti',
#   u'translat',
#   'may',
#   'certain',
#   'extent',
#   'shift',
#   u'mean',
#   u'translat',
#   'text',
#   u'thu',
#   u'subsequ',
#   u'translat',
#   u'provid',
#   u'result',
#   u'differ',
#   u'origin',
#   'second',
#   u'import',
#   'reason',
#   'lack',
#   u'translat',
#   'pivot',
#   'target',
#   u'languag',
#   u'usual',
#   'problem',
#   u'translat',
#   u'sourc',
#   u'directli',
#   'target',
#   u'languag',
#   u'translat',
#   u'memori',
#   'key',
#   'main',
#   'goal',
#   'paper',
#   'suggest',
#   u'overcom',
#   u'obstacl',
#   u'mean',
#   u'combin',
#   'system',
#   u'commerci',
#   'maht',
#   u'machin',
#   u'aid',
#   'human',
#   u'translat',
#   u'system',
#   'chosen',
#   u'trado',
#   u'translat',
#   'workbench',
#   u'repres',
#   'system',
#   u'class',
#   u'product',
#   'can',
#   u'character',
#   u'exampl',
#   u'base',
#   u'translat',
#   u'tool',
#   'ibm',
#   u'translat',
#   u'manag',
#   u'product',
#   'also',
#   'belong',
#   u'class',
#   u'system',
#   u'use',
#   u'call',
#   u'translat',
#   u'memori',
#   u'contain',
#   u'pair',
#   u'previous',
#   u'translat',
#   u'sentenc',
#   u'sourc',
#   'target',
#   u'languag',
#   'human',
#   u'translat',
#   u'start',
#   u'translat',
#   'new',
#   u'sentenc',
#   'system',
#   u'tri',
#   'match',
#   u'sourc',
#   u'sentenc',
#   u'alreadi',
#   u'store',
#   u'translat',
#   u'memori',
#   u'success',
#   u'suggest',
#   u'translat',
#   'human',
#   u'translat',
#   u'decid',
#   'whether',
#   'use',
#   u'modifi',
#   'reject',
#   u'segment',
#   u'translat',
#   u'memori',
#   'key',
#   u'featur',
#   'system',
#   u'translat',
#   u'memori',
#   'may',
#   u'export',
#   'text',
#   'file',
#   u'thu',
#   u'allow',
#   u'easi',
#   u'manipul',
#   'content',
#   'let',
#   u'suppos',
#   u'dispos',
#   'two',
#   u'translat',
#   u'memori',
#   'one',
#   'human',
#   'made',
#   u'sourc',
#   'pivot',
#   u'languag',
#   'pair',
#   u'creat',
#   'system',
#   'pivot',
#   'target',
#   u'languag',
#   'pair',
#   u'substitut',
#   u'segment',
#   'pivot',
#   u'languag',
#   u'segment',
#   'target',
#   u'languag',
#   u'routin',
#   u'procedur',
#   'human',
#   u'translat',
#   u'translat',
#   u'sourc',
#   u'languag',
#   'target',
#   u'languag',
#   u'get',
#   u'translat',
#   u'memori',
#   u'requir',
#   'pair',
#   u'sourc',
#   'target',
#   'system',
#   u'penalti',
#   u'appli',
#   u'trado',
#   u'translat',
#   'workbench',
#   'similar',
#   'system',
#   u'guarante',
#   ...]]

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)

# %%
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
# generate LDA model
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=2, id2word = dictionary, passes=20)

# %%
ldamodel.save('ldamodel')

# %%
m1 = gensim.models.ldamodel.LdaModel.load('ldamodel')

# %%
print(m1.print_topics(num_topics=2, num_words=5))
# Out:
# [(0, u'0.034*"translat" + 0.022*"system" + 0.021*"languag" + 0.015*"czech" + 0.009*"word"'), (1, u'0.018*"system" + 0.011*"languag" + 0.011*"grammar" + 0.010*"natur" + 0.008*"queri"')]

# %%
print(ldamodel.print_topics(num_topics=2, num_words=5))
# Out:
# [(0, u'0.034*"translat" + 0.022*"system" + 0.021*"languag" + 0.015*"czech" + 0.009*"word"'), (1, u'0.018*"system" + 0.011*"languag" + 0.011*"grammar" + 0.010*"natur" + 0.008*"queri"')]

# %%
ldamodel[corpus[0]]
# Out:
# [(0, 0.84984623341586552), (1, 0.1501537665841344)]

# %%
ldamodel.inference([corpus[0]])
# Out:
# (array([[ 1698.84685903,   300.15314097]]), None)

# %%
def get_doc_topics(lda, bow):
    gamma, _ = lda.inference([bow])
    
    topic_dist = gamma[0] / sum(gamma[0])  # normalize distribution
    
    return [(topicid, topicvalue) for topicid, topicvalue in enumerate(topic_dist)]

# %%
get_doc_topics(ldamodel, corpus[0])
# Out:
# [(0, 0.84985114445041054), (1, 0.15014885554958948)]

# %%
topic_dist = []
for j in xrange(len(corpus)):
    topic_dist.append(k[1] for k in get_doc_topics(ldamodel, corpus[j]))
for entry in topic_dist:
    print entry
# Out:
# <generator object <genexpr> at 0x7f6f6277adc0>
# <generator object <genexpr> at 0x7f6f6277ae10>
# <generator object <genexpr> at 0x7f6f6277aeb0>
# <generator object <genexpr> at 0x7f6f60b74050>
# <generator object <genexpr> at 0x7f6f60b74190>
# <generator object <genexpr> at 0x7f6f60b74320>
# <generator object <genexpr> at 0x7f6f60b740a0>
# <generator object <genexpr> at 0x7f6f60b741e0>
# <generator object <genexpr> at 0x7f6f60b74370>
# <generator object <genexpr> at 0x7f6f60b743c0>
# <generator object <genexpr> at 0x7f6f60b74410>
# <generator object <genexpr> at 0x7f6f60b744b0>
# <generator object <genexpr> at 0x7f6f60b74280>
# <generator object <genexpr> at 0x7f6f60b74640>
# <generator object <genexpr> at 0x7f6f60b745a0>
# <generator object <genexpr> at 0x7f6f60b74690>
# <generator object <genexpr> at 0x7f6f60b742d0>
# <generator object <genexpr> at 0x7f6f60b745f0>
# <generator object <genexpr> at 0x7f6f60b747d0>
# <generator object <genexpr> at 0x7f6f60b74730>
# [0.13657695927366442, 0.86342304072633558]
# [0.99974736288482424, 0.00025263711517575321]
# [0.99959685978008272, 0.00040314021991725316]
# [0.99952691585509967, 0.00047308414490033237]
# [0.99959124564001434, 0.00040875435998560881]
# [0.99974649776732016, 0.00025350223267979005]
# [0.99960356634586045, 0.0003964336541396131]
# [0.99646033912803833, 0.003539660871961683]
# [0.99968138340084933, 0.00031861659915056773]
# [0.99966624584820463, 0.00033375415179540553]
# [0.99961995615107158, 0.00038004384892844891]
# [0.34152489660848878, 0.65847510339151127]
# [0.99962034392773058, 0.00037965607226940636]
# [0.99931150215778231, 0.00068849784221760484]
# [0.00036169108870022997, 0.99963830891129968]
# [0.00021726833945044324, 0.99978273166054954]
# [0.00027953189639589048, 0.99972046810360415]
# [0.024682830014595453, 0.97531716998540452]
# [0.99949883589728805, 0.00050116410271191061]
# 50

# %%
ldamodel.get_document_topics(corpus[0])
# Out:
# [(0, 0.99961207911446837)]

# %%
ldamodel[corpus[0]]
# Out:
# [(0, 0.94263649115196291), (1, 0.057363508848037148)]

# %%
#JSDiv_0
from scipy.stats import entropy
from numpy.linalg import norm
import numpy as np

def JSD(P, Q):
    _P = P / norm(P, ord=1)
    _Q = Q / norm(Q, ord=1)
    _M = 0.5 * (_P + _Q)
    return 0.5 * (entropy(_P, _M) + entropy(_Q, _M))

# %%
# JSDiv_1
def jsdiv(P, Q):
    """Compute the Jensen-Shannon divergence between two probability distributions.

    Input
    -----
    P, Q : array-like
        Probability distributions of equal length that sum to 1
    """

    def _kldiv(A, B):
        return np.sum([v for v in A * np.log2(A/B) if not np.isnan(v)])

    P = np.array(P)
    Q = np.array(Q)

    M = 0.5 * (P + Q)

    return 0.5 * (_kldiv(P, M) +_kldiv(Q, M))

# %%
a = (9,0)

# %%
type(a)
# Out:
# tuple

# %%
a[1]
# Out:
# 0

# %%
JSD(pd[0],pd[1])
# Out:
# 0.41400665037249312

# %%
JSD(pd[0],pd[4])
# Out:
# 0.4523300746974277

# %%
JSD(pd[2],pd[4])
# Out:
# 0.029809960143430105

# %%
JSD(pd[3],pd[4])
# Out:
# 0.0012743512921435996

# %%
JSD(pd[0],pd[2])
# Out:
# 0.30687543131537759

# %%
JSD(pd[2],pd[2])
# Out:
# 0.0

# %%
div_mat = np.zeros((50,50))
for i in xrange(50):
    for j in xrange(50):
        div_mat[i][j] = JSD(pd[i],pd[j])

# %%
div_mat[0]
# Out:
# array([  0.00000000e+00,   4.14006650e-01,   3.06875431e-01,
#          4.67564559e-01,   4.52330075e-01,   4.68714447e-01,
#          4.69214960e-01,   4.68975633e-01,   4.68964416e-01,
#          4.68784871e-01,   5.18164066e-02,   1.84341683e-04,
#          3.01718669e-01,   4.69406146e-01,   4.68865046e-01,
#          4.69192375e-01,   4.68975811e-01,   4.66101139e-01,
#          3.95243674e-01,   4.46955636e-01,   5.41480108e-02,
#          5.29105483e-02,   5.10064896e-02,   5.08351359e-02,
#          5.43090286e-02,   4.55309427e-01,   5.42758858e-02,
#    7.89730533e-03   6.68938886e-03   6.93018982e-04   2.07105219e-03
#    6.33683528e-01   6.31847145e-01   6.28837576e-01   6.28557562e-01
#    6.33913220e-01   3.59789206e-03   6.33866157e-01   6.16680695e-01
#    6.66914726e-03   6.33287055e-01   6.33658258e-01   2.30833626e-02
#    6.33804662e-01   6.33203950e-01   6.32935185e-01   6.33182166e-01
#    6.33801100e-01   6.33230024e-01   6.23297115e-01   6.33536984e-01
#    6.33476592e-01   6.33293985e-01   9.71752514e-02   6.33295503e-01
#    6.32137280e-01   7.80876084e-03   8.08223506e-03   7.95986806e-03
#    0.00000000e+00   6.32828787e-01]
# [  5.35624995e-02   6.30768877e-01   5.10896514e-01   6.88104372e-01
#    6.72035281e-01   6.89302176e-01   6.89822133e-01   6.89573636e-01
#    6.89561984e-01   6.89375396e-01   8.58603045e-05   4.83825976e-02
#    5.04959094e-01   6.90020452e-01   6.89458731e-01   6.89798694e-01
#    6.89573822e-01   6.86575109e-01   6.10237429e-01   6.66310036e-01
#    1.55027654e-05   1.42697079e-05   1.66080547e-04   1.85448071e-04
#    2.65955404e-05   6.75198399e-01   2.40078949e-05   1.38397631e-03
#    6.86518819e-01   4.04711335e-06   1.45034553e-05   4.82355159e-01
#    2.08807187e-05   2.66280216e-06   2.02458027e-07   2.35136123e-06
#    2.07081213e-05   3.06329183e-06   6.44209760e-04   1.02522123e-05
#    8.45252777e-06   4.17697270e-06   3.10640083e-01   4.20570905e-06
#    7.40994280e-06   6.89378621e-01   6.89967670e-01   6.89709203e-01
#    6.32828787e-01   0.00000000e+00]

# %%
s = "¿qué?"
u = unicode(s, "utf-8")

# %%
u
# Out:
# u'\xbfqu\xe9?'

# %%
if u:
    print 6
# Out:
# 6

# %%
def gen_ind_graph(paper_id, out_net, in_net,facet):
    
    nodes = []
    out_1 = out_net[paper_id][facet]
    in_1 = in_net[paper_id][facet]
    nodes=nodes+out_1+in_1                           ## adds all 1-hop papers...
   
                               
    for paper in out_1:                              ## adds all 2-hop papers...
        nodes=nodes+out_net[paper][facet]
        nodes=nodes+in_net[paper][facet]
    for paper in in_1:
        nodes=nodes+out_net[paper][facet]
        nodes=nodes+in_net[paper][facet]
    
    nodes = nodes + cos_sim_top(paper_id)            ## adds papers above COS_LIMIT

    node_set = set(nodes)                            ## takes unique values only...
    nodes = list(node_set)
    
    tpm = np.zeros((len(nodes),len(nodes)))
    graph = []
    
    for i in range(1,len(nodes)):
        for j in range(0,i):
            p1 = nodes[i]
            p2 = nodes[j]
            if (p1 in out_net[p2][facet]) or (p2 in out_net[p1][facet]) or (cos_sim(p1,p2)>COS_LIMIT):
                tpm[i][j] = cos_sim(p1,p2)
                tpm[j][i] = tpm[i][j]
    for i in xrange(len(nodes)):
        tpm[i] = tpm[i]/float(np.sum(tpm[i]))*0.9 
        tpm[i]+= (1-np.sum(tpm[i]))/len(nodes)
        
    for i in range(0,len(nodes)):
        for j in range(0,len(nodes)):    
            graph.append([nodes[i], nodes[j], tpm[i,j]])
                
    return graph
