# %%
import pandas as pd
import numpy as np

#reading data
network = pd.read_csv("network.csv")
incite = {}
outcite = {}
for row in network.iterrows():
    if(type(row[1][1])!=str):
        incite[row[1][0]] = []
    else:
        incite[row[1][0]] = row[1][1].split(',')
    if(type(row[1][2])!=str):
        outcite[row[1][0]] = []
    else:
        outcite[row[1][0]] = row[1][2].split(',')

# %%
outcite
# Out:
# {'A00-1001': ['J82-3002'],
#  'A00-1002': ['C90-3057', 'P98-1080'],
#  'A00-1003': ['P98-1066', 'P99-1027', 'P99-1029'],
#  'A00-1004': ['A00-1019',
#   'J93-1006',
#   'J93-2003',
#   'P91-1022',
#   'P91-1023',
#   'P93-1002',
#   'P94-1012'],
#  'A00-1005': ['J86-3001', 'J99-3003', 'P96-1009'],
#  'A00-1006': ['C96-1070', 'P98-2131', 'P98-2185', 'W97-0403'],
#  'A00-1007': ['J96-2004'],
#  'A00-1008': ['A00-2041', 'J86-3001', 'P98-1059'],
#  'A00-1009': ['A92-1006',
#   'A97-1037',
#   'A97-1039',
#   'C92-3158',
#   'J85-1003',
#   'J94-4004'],
#  'A00-1010': ['H94-1010', 'P96-1008', 'W00-0303'],
#  'A00-1011': ['M95-1019', 'M98-1011', 'M98-1012', 'W95-0107'],
#  'A00-1012': ['A92-1021',
#   'A94-1013',
#   'A97-1001',
#   'A97-1004',
#   'J96-2004',
#   'P98-2140'],
#  'A00-1013': ['A92-1021'],
#  'A00-1014': ['A00-2027',
#   'H91-1014',
#   'J99-3003',
#   'P88-1015',
#   'P90-1010',
#   'P97-1035',
#   'P98-2129',
#   'P99-1024',
#   'W00-0310'],
#  'A00-1015': ['P98-2195'],
#  'A00-1016': ['A97-1001', 'A97-1008', 'P93-1008', 'P94-1001', 'P99-1024'],
#  'A00-1017': ['J95-2003', 'J98-3004', 'W94-0319'],
#  'A00-1018': ['C96-2129',
#   'J90-2002',
#   'J93-2003',
#   'J94-2001',
#   'J94-3001',
#   'P91-1023'],
#  'A00-1019': ['C94-1101',
#   'C96-1070',
#   'C96-1089',
#   'C96-1097',
#   'J93-1003',
#   'J93-2003',
#   'J96-1002',
#   'P93-1003',
#   'P94-1032',
#   'P94-1033',
#   'P95-1032',
#   'P96-1003',
#   'P97-1061',
#   'P98-2162',
#   'P98-2221',
#   'P98-2230',
#   'P99-1041',
#   'W97-0311'],
#  'A00-1020': ['A92-1021',
#   'A94-1006',
#   'A97-1050',
#   'C96-1021',
#   'J94-4002',
#   'J96-1001',
#   'M93-1019',
#   'P98-2143',
#   'P99-1048',
#   'W97-0319',
#   'W97-1306',
#   'W97-1307',
#   'W98-1119',
#   'W99-0104',
#   'W99-0611'],
#  'A00-1021': ['A97-1030', 'A97-1033'],
#  'A00-1022': ['A97-1031', 'W97-0802'],
#  'A00-1023': ['A97-1029', 'M98-1015', 'M98-1027'],
#  'A00-1024': ['A88-1019',
#   'A92-1015',
#   'J83-3005',
#   'P98-1003',
#   'P98-1059',
#   'P98-1081',
#   'P98-2142',
#   'W98-1111'],
#  'A00-1025': ['E99-1011', 'J93-2004', 'P98-1034'],
#  'A00-1026': ['A88-1019',
#   'A92-1018',
#   'A97-1012',
#   'A97-1013',
#   'A97-1030',
#   'A97-1046',
#   'J93-2006',
#   'P83-1019',
#   'P92-1003',
#   'P99-1001',
#   'P99-1050',
#   'X98-1031'],
#  'A00-1027': ['C94-1101', 'P94-1010', 'P98-1059', 'W98-1110'],
#  'A00-1028': ['E93-1006',
#   'P94-1026',
#   'P94-1040',
#   'P95-1036',
#   'P96-1030',
#   'P97-1028',
#   'P98-1022'],
#  'A00-1029': ['C90-3035', 'J92-1004'],
#  'A00-1030': ['A00-1036'],
#  'A00-1031': ['A92-1018',
#   'A97-1014',
#   'J93-2004',
#   'P98-1081',
#   'W96-0102',
#   'W96-0213'],
#  'A00-1032': ['C92-4173', 'C94-1032', 'J97-2002', 'J97-4004', 'P99-1036'],
#  'A00-1033': ['A97-1031', 'J95-2004'],
#  'A00-1034': ['A97-1029', 'J97-2003', 'M98-1015', 'M98-1018', 'P99-1021'],
#  'A00-1035': ['A88-1011',
#   'A92-1015',
#   'A97-1022',
#   'A97-1024',
#   'C92-3155',
#   'C96-1031'],
#  'A00-1036': [],
#  'A00-1037': ['P98-2180'],
#  'A00-1038': ['A97-1049', 'M95-1018', 'P99-1009'],
#  'A00-1039': ['A97-1011',
#   'J86-3002',
#   'J93-1006',
#   'M92-1021',
#   'M95-1011',
#   'M98-1009',
#   'P93-1022',
#   'P93-1024'],
#  'A00-1040': ['A92-1021', 'C96-1071', 'E99-1001', 'M98-1015'],
#  'A00-1041': ['W99-0613'],
#  'A00-1042': ['A88-1019',
#   'A97-1044',
#   'J93-1007',
#   'P96-1003',
#   'W98-0610',
#   'W99-0625'],
#  'A00-1043': ['A00-2024', 'C96-2183', 'P98-1099', 'P99-1045'],
#  'A00-1044': ['A97-1029'],
#  'A00-1045': ['C96-2120'],
#  'A00-1046': ['A97-1001', 'H93-1074', 'P80-1036', 'P97-1036', 'P98-2136'],
#  'A00-2001': ['P94-1001'],
#  'A00-2002': ['C94-2183',
#   'H94-1024',
#   'J93-1004',
#   'P95-1037',
#   'P97-1062',
#   'P99-1047',
#   'W99-0307'],
#  'A00-2003': ['J95-2003',
#   'J96-2004',
#   'J97-1007',
#   'P97-1005',
#   'P98-1011',
#   'W98-1119',
#   'W99-0107',
#   'W99-0108',
#   'W99-0611'],
#  'A00-2004': ['A94-1013',
#   'A97-1004',
#   'C94-2183',
#   'J91-1002',
#   'P93-1001',
#   'P93-1041',
#   'P94-1002',
#   'P94-1050',
#   'P95-1015',
#   'P97-1048',
#   'P98-2145',
#   'P98-2244',
#   'P99-1046',
#   'P99-1077',
#   'W97-0304',
#   'W98-1123'],
#  'A00-2005': ['J93-2004', 'P97-1003', 'P98-1083', 'W99-0606', 'W99-0623'],
#  'A00-2006': ['P98-2180'],
#  'A00-2007': ['E99-1023',
#   'J93-2004',
#   'P98-1010',
#   'P98-1029',
#   'P98-1034',
#   'P98-1081',
#   'W95-0107',
#   'W99-0621',
#   'W99-0708'],
#  'A00-2008': ['P98-1013', 'P98-1071', 'W97-0204'],
#  'A00-2009': ['A97-1056',
#   'H93-1051',
#   'J98-1005',
#   'J98-1006',
#   'P94-1020',
#   'P96-1006',
#   'P98-1029',
#   'W96-0208',
#   'W99-0623'],
#  'A00-2010': [],
#  'A00-2011': ['J90-2002',
#   'P91-1022',
#   'P91-1023',
#   'P98-2127',
#   'P99-1068',
#   'W99-0905'],
#  'A00-2012': ['C94-1029', 'C96-1017', 'J92-1003', 'P98-1018'],
#  'A00-2013': ['A88-1019',
#   'A97-1017',
#   'J94-2001',
#   'J95-4004',
#   'P98-1029',
#   'P98-1080',
#   'W96-0102',
#   'W96-0213'],
#  'A00-2014': ['J92-1004', 'P90-1005'],
#  'A00-2015': ['C96-1058', 'P94-1013', 'P96-1025', 'P98-1083'],
#  'A00-2016': ['J93-2004', 'P97-1003', 'P97-1062'],
#  'A00-2017': ['A97-1011',
#   'J95-4004',
#   'P94-1013',
#   'P98-1035',
#   'P98-2186',
#   'P99-1004',
#   'P99-1005',
#   'W99-0621'],
#  'A00-2018': ['J93-2004',
#   'J96-1002',
#   'J98-2004',
#   'J98-4004',
#   'P95-1037',
#   'P97-1003',
#   'W98-1115',
#   'W99-0623'],
#  'A00-2019': ['H93-1052', 'J98-1006', 'P98-2196', 'W95-0104'],
#  'A00-2020': ['J93-2004', 'J93-2006', 'P98-1029', 'W96-0213', 'W99-0606'],
#  'A00-2021': ['J97-4005', 'P99-1014', 'P99-1069'],
#  'A00-2022': ['A92-1012',
#   'P85-1018',
#   'P89-1018',
#   'P91-1041',
#   'P99-1061',
#   'P99-1075'],
#  'A00-2023': ['C96-2155', 'J93-2004', 'P95-1034', 'P96-1027', 'P98-1116'],
#  'A00-2024': ['A00-1043', 'P98-1099', 'P99-1072'],
#  'A00-2025': [],
#  'A00-2026': ['A97-1039', 'J96-1002', 'J97-2001', 'P98-1116'],
#  'A00-2027': ['A00-1014', 'P96-1009', 'P97-1035'],
#  'A00-2028': ['H92-1009',
#   'J99-3003',
#   'P98-1122',
#   'P98-2219',
#   'P99-1025',
#   'P99-1040'],
#  'A00-2029': ['P98-1122', 'P99-1040'],
#  'A00-2030': ['A97-1029',
#   'J93-2004',
#   'J93-2006',
#   'P96-1025',
#   'P97-1003',
#   'W97-0302'],
#  'A00-2031': ['H90-1053', 'J96-1002', 'P97-1003', 'W97-0301'],
#  'A00-2032': ['A92-1022',
#   'C94-1032',
#   'C94-1101',
#   'C96-2136',
#   'H93-1037',
#   'H93-1045',
#   'H94-1054',
#   'J96-3004',
#   'P97-1041',
#   'P98-1068',
#   'P98-1108',
#   'P98-2206',
#   'W96-0113',
#   'W96-0205',
#   'W97-0120',
#   'W97-1008'],
#  'A00-2033': ['A97-1001', 'J93-2004', 'P98-1101'],
#  'A00-2034': ['A97-1052',
#   'C96-1055',
#   'E99-1007',
#   'J87-3002',
#   'J93-1005',
#   'J98-3003',
#   'P98-1046',
#   'P98-2247',
#   'P99-1004',
#   'P99-1051',
#   'W96-0303'],
#  'A00-2035': ['A97-1004',
#   'H89-2048',
#   'J93-2004',
#   'J97-2002',
#   'M95-1012',
#   'P99-1021'],
#  'A00-2036': ['E87-1037',
#   'J97-3004',
#   'P94-1017',
#   'P96-1023',
#   'P96-1032',
#   'P97-1003',
#   'P98-1035',
#   'P99-1059',
#   'W97-0301'],
#  'A00-2037': ['P94-1014', 'P97-1034'],
#  'A00-2038': ['J96-4002',
#   'J96-4003',
#   'J99-2005',
#   'P98-1043',
#   'P98-2200',
#   'W97-1102'],
#  'A00-2039': ['A00-2039',
#   'C94-1029',
#   'C96-1017',
#   'J94-1003',
#   'J94-3001',
#   'P98-2240',
#   'W98-1312'],
#  'A00-2040': ['E99-1017',
#   'J94-3001',
#   'J95-4004',
#   'P95-1003',
#   'P98-2188',
#   'W99-0705'],
#  'A00-2041': ['A97-1012',
#   'C94-1042',
#   'J97-3004',
#   'P98-2229',
#   'P99-1052',
#   'W94-0113'],
#  'A00-2042': [],
#  'A00-2043': ['C96-1003',
#   'C96-1016',
#   'C96-1024',
#   'C96-1086',
#   'J93-3001',
#   'J98-1004',
#   'P88-1011',
#   'P89-1005',
#   'P96-1001',
#   'P97-1021',
#   'P97-1050'],
#  'A00-3001': ['J95-2003', 'P98-2242', 'W94-0319', 'W98-1411'],
#  'A00-3002': ['C92-3168', 'P96-1030'],
#  'A00-3003': ['A92-1009', 'J93-4004', 'P99-1058', 'W94-0332'],
#  'A00-3004': ['C94-1082'],
#  'A00-3005': ['C92-2072',
#   'J83-3003',
#   'P89-1013',
#   'P96-1010',
#   'P98-1003',
#   'P98-1063',
#   'P98-2142'],
#  'A00-3006': ['C90-2036', 'P95-1026'],
#  'A00-3007': ['C92-2070',
#   'C96-1005',
#   'H93-1051',
#   'J98-1001',
#   'W97-0213',
#   'W98-0705',
#   'X96-1035'],
#  'A00-3008': ['C94-1103', 'C96-1050', 'J92-4007', 'W98-0315'],
#  'A83-1001': [],
#  'A83-1002': ['P79-1023'],
#  'A83-1003': [],
#  'A83-1004': ['P82-1008', 'P82-1014'],
#  'A83-1005': ['C82-1066'],
#  'A83-1006': ['C82-1015', 'P81-1028'],
#  'A83-1007': ['C80-1075', 'C82-1014', 'C82-2029'],
#  'A83-1008': [],
#  'A83-1009': [],
#  'A83-1010': ['T75-2001'],
#  'A83-1011': ['C82-2040', 'P82-1011'],
#  'A83-1012': [],
#  'A83-1013': ['C82-1015'],
#  'A83-1014': ['A83-1015',
#   'A83-1016',
#   'A83-1017',
#   'C80-1008',
#   'C80-1027',
#   'J80-1002',
#   'J81-2002',
#   'J81-4004',
#   'T78-1029'],
#  'A83-1015': ['J80-2003', 'J81-2002', 'J81-4002', 'P82-1015', 'P82-1016'],
#  'A83-1016': ['C82-1014', 'C82-1032', 'J81-2002'],
#  'A83-1017': [],
#  'A83-1018': [],
#  'A83-1019': ['P79-1024', 'P79-1026', 'T75-2010'],
#  'A83-1020': ['P81-1030'],
#  'A83-1021': ['P80-1040'],
#  'A83-1022': [],
#  'A83-1023': [],
#  'A83-1024': ['J81-4001'],
#  'A83-1025': [],
#  'A83-1026': [],
#  'A83-1027': ['C80-1013',
#   'C80-1030',
#   'C80-1032',
#   'C82-1028',
#   'P81-1028',
#   'P82-1001',
#   'P82-1003'],
#  'A83-1028': ['C80-1065',
#   'C80-1066',
#   'J80-1001',
#   'J81-1003',
#   'J81-4002',
#   'P80-1025'],
#  'A83-1029': ['C80-1069', 'C82-1004', 'C82-1034'],
#  'A83-1030': [],
#  'A83-1031': ['J80-2001', 'J81-1003', 'P81-1035'],
#  'A83-1032': [],
#  'A83-1033': [],
#  'A88-1001': ['J81-4001', 'J86-2002', 'P83-1007', 'P85-1022', 'P87-1022'],
#  'A88-1002': ['P85-1019'],
#  'A88-1003': ['P86-1034', 'P87-1022'],
#  'A88-1004': ['C86-1072', 'C86-1132', 'C86-1149', 'C86-1154', 'P83-1022'],
#  'A88-1005': [],
#  'A88-1006': [],
#  'A88-1007': ['A83-1003',
#   'A83-1006',
#   'J86-3002',
#   'P84-1102',
#   'P86-1004',
#   'P86-1005',
#   'P87-1005'],
#  'A88-1008': ['J82-1003', 'J82-3002', 'P83-1009'],
#  'A88-1009': ['J80-2003',
#   'J81-2002',
#   'J83-3001',
#   'J83-3003',
#   'J83-3005',
#   'J86-2001'],
#  'A88-1010': ['J83-3003', 'P81-1036'],
#  'A88-1011': [],
#  'A88-1012': ['J83-3002', 'J87-3003', 'P84-1036', 'P84-1095', 'P85-1037'],
#  'A88-1013': ['J83-3001', 'J83-3005', 'P86-1005'],
#  'A88-1014': ['J79-1083', 'P79-1007', 'P85-1033', 'P85-1037', 'T75-2013'],
#  'A88-1015': ['P82-1010', 'P86-1036'],
#  'A88-1016': ['C86-1126', 'E87-1031'],
#  'A88-1017': ['P86-1005'],
#  'A88-1018': ['H86-1003', 'P86-1017', 'P87-1026'],
#  'A88-1019': ['A88-1030'],
#  'A88-1020': ['A88-1012', 'J87-3005', 'P85-1037'],
#  'A88-1021': ['J87-3005', 'P86-1018', 'T75-2001'],
#  'A88-1022': ['C86-1071', 'J85-2005', 'P84-1050'],
#  'A88-1023': ['A83-1028', 'C86-1024', 'E85-1010', 'J85-2002'],
#  'A88-1024': [],
#  'A88-1025': ['P84-1066', 'P84-1078'],
#  'A88-1026': ['P85-1008', 'P86-1005', 'P87-1005'],
#  'A88-1027': ['J83-3002', 'P82-1015', 'P86-1002'],
#  'A88-1028': [],
#  'A88-1029': ['J81-2002', 'P85-1021', 'T75-2013'],
#  'A88-1030': ['A88-1019', 'P86-1022'],
#  'A88-1031': ['C86-1063', 'C86-1065', 'C86-1066', 'J85-2002'],
#  'A88-1032': ['J82-3004', 'J86-3006', 'P83-1009', 'P85-1008'],
#  'A88-1033': ['J79-1045', 'J79-1061', 'P82-1015', 'P84-1102'],
#  'A88-1034': ['C86-1045', 'J82-3004', 'P83-1020', 'P85-1008'],
#  'A92-1001': ['P86-1036', 'P88-1012'],
#  'A92-1002': ['C86-1138',
#   'J81-4004',
#   'J86-1002',
#   'J86-3001',
#   'J88-3006',
#   'P86-1032',
#   'P88-1015',
#   'P90-1010',
#   'P91-1004'],
#  'A92-1003': ['J87-1005', 'J89-1001', 'P88-1003', 'P89-1024', 'P90-1029'],
#  'A92-1004': ['A88-1016', 'J89-2002', 'J90-3003'],
#  'A92-1005': ['C86-1138', 'C88-1040'],
#  'A92-1006': ['A88-1004', 'P84-1065', 'P88-1020', 'W90-0112'],
#  'A92-1007': ['C90-3059', 'C90-3079', 'E91-1003', 'P83-1022'],
#  'A92-1008': ['E91-1003'],
#  'A92-1009': ['C92-1038',
#   'H89-1022',
#   'J86-3001',
#   'P83-1023',
#   'P89-1025',
#   'P92-1034'],
#  'A92-1010': ['E91-1003', 'H89-1022', 'J86-3001', 'P86-1016'],
#  'A92-1011': ['A92-1012', 'C88-2166', 'C90-2007', 'P81-1030'],
#  'A92-1012': ['A92-1011',
#   'A92-1044',
#   'C90-2008',
#   'E89-1000',
#   'J91-4003',
#   'W91-0209'],
#  'A92-1013': ['C90-1005',
#   'C90-3010',
#   'E87-1006',
#   'E87-1040',
#   'J89-1002',
#   'J90-1003',
#   'P89-1022',
#   'P90-1032',
#   'P90-1034',
#   'P91-1019',
#   'P91-1027',
#   'P91-1030',
#   'P91-1036',
#   'W91-0212'],
#  'A92-1014': ['C90-1005',
#   'C90-3010',
#   'C92-2085',
#   'E85-1013',
#   'E85-1024',
#   'J90-1003',
#   'J90-2002',
#   'P91-1030'],
#  'A92-1015': ['A88-1011', 'A88-1027', 'C88-2127', 'E91-1013'],
#  'A92-1016': ['C73-2019', 'C90-2064', 'J87-3008'],
#  'A92-1017': ['A88-1011',
#   'A92-1015',
#   'C86-1001',
#   'C90-1018',
#   'C90-2063',
#   'E91-1027'],
#  'A92-1018': ['A88-1019', 'C90-2040', 'H89-1054', 'H89-2014', 'J88-1003'],
#  'A92-1019': [],
#  'A92-1020': ['A88-1019', 'A88-1030', 'J88-1003', 'P88-1025', 'P88-1026'],
#  'A92-1021': ['A88-1019',
#   'A92-1018',
#   'H89-2014',
#   'H91-1065',
#   'J88-1003',
#   'P89-1015'],
#  'A92-1022': ['C90-3071',
#   'H90-1053',
#   'H91-1059',
#   'H91-1060',
#   'J83-3002',
#   'P84-1005'],
#  'A92-1023': ['H89-1032',
#   'H89-2019',
#   'H90-1021',
#   'H90-1023',
#   'H91-1008',
#   'H91-1060',
#   'H91-1062',
#   'H92-1064',
#   'M91-1001'],
#  'A92-1024': ['C88-1072', 'H86-1010', 'P88-1012'],
#  'A92-1025': ['H91-1066', 'M91-1007'],
#  'A92-1026': ['C90-3029',
#   'H89-2011',
#   'H91-1034',
#   'H91-1036',
#   'H91-1037',
#   'H91-1066',
#   'P90-1031'],
#  'A92-1027': ['J89-2002', 'P83-1019'],
#  'A92-1028': ['C88-2159', 'P83-1007', 'P86-1031'],
#  'A92-1029': ['E89-1025', 'E89-1037', 'E91-1050', 'J82-3004', 'P84-1109'],
#  'A92-1030': ['C88-2121',
#   'C88-2147',
#   'C90-3001',
#   'C90-3045',
#   'C92-3145',
#   'W90-0102'],
#  'A92-1031': ['P91-1022'],
#  'A92-1032': ['C90-3029', 'J83-3001', 'J83-3002', 'J91-2002'],
#  'A92-1033': [],
#  'A92-1034': ['A88-1031', 'P87-1010'],
#  'A92-1035': [],
#  'A92-1036': ['A88-1006'],
#  'A92-1037': [],
#  'A92-1038': [],
#  'A92-1039': [],
#  'A92-1040': ['E89-1004', 'J86-3001'],
#  'A92-1041': ['E89-1020'],
#  'A92-1042': [],
#  'A92-1043': [],
#  'A92-1044': [],
#  'A92-1045': ['A88-1026', 'P87-1005'],
#  'A92-1046': [],
#  'A92-1047': [],
#  'A94-1001': ['C92-3158'],
#  'A94-1002': ['A92-1006',
#   'C90-3059',
#   'C92-3158',
#   'H90-1009',
#   'P83-1022',
#   'P89-1025'],
#  'A94-1003': ['A94-1004', 'C94-2108'],
#  'A94-1004': ['A92-1025', 'A94-1003', 'C94-2108'],
#  'A94-1005': ['C92-2097', 'C92-2101', 'P91-1024'],
#  'A94-1006': ['A88-1019',
#   'C90-3031',
#   'C92-3150',
#   'E93-1015',
#   'H91-1026',
#   'J90-1003',
#   'J90-2002',
#   'J93-1006',
#   'J93-1007',
#   'J93-2003',
#   'P88-1025',
#   'P91-1022',
#   'P91-1023',
#   'P91-1034',
#   'P93-1001',
#   'P93-1003',
#   'P93-1004',
#   'W93-0301'],
#  'A94-1007': ['C92-1029',
#   'E83-1013',
#   'H93-1036',
#   'H93-1054',
#   'H94-1025',
#   'P84-1053',
#   'P85-1014',
#   'P85-1023',
#   'P86-1013'],
#  'A94-1008': ['A92-1018',
#   'C90-3030',
#   'C94-1092',
#   'C94-1104',
#   'E93-1046',
#   'H89-1054',
#   'J93-2006',
#   'P90-1031'],
#  'A94-1009': ['A88-1019',
#   'A92-1018',
#   'A92-1021',
#   'H89-1054',
#   'J88-1003',
#   'J93-2004',
#   'J94-2001'],
#  'A94-1010': ['H91-1057',
#   'H94-1013',
#   'H94-1014',
#   'H94-1040',
#   'J93-1002',
#   'J94-4005',
#   'P93-1024'],
#  'A94-1011': ['A88-1019', 'H91-1061', 'H92-1041', 'H93-1070', 'P90-1034'],
#  'A94-1012': ['C94-2134', 'E93-1027', 'J93-1002', 'J93-2003', 'P91-1027'],
#  'A94-1013': ['A88-1019', 'A92-1018', 'H89-2048', 'J93-1004', 'J93-1006'],
#  'A94-1014': ['H91-1066',
#   'M91-1022',
#   'M91-1028',
#   'M91-1030',
#   'M91-1033',
#   'M92-1001',
#   'P83-1007',
#   'P84-1024',
#   'P90-1031'],
#  'A94-1015': [],
#  'A94-1016': ['E93-1062', 'H93-1038', 'J90-2002'],
#  'A94-1017': ['C92-2097'],
#  'A94-1018': ['C88-1075',
#   'C88-2118',
#   'J83-3001',
#   'J83-3003',
#   'P83-1019',
#   'P89-1013',
#   'P92-1006',
#   'P92-1008'],
#  'A94-1019': ['C92-4174',
#   'E89-1001',
#   'E93-1011',
#   'H92-1040',
#   'J92-4004',
#   'P86-1038',
#   'P87-1013',
#   'P94-1027'],
#  'A94-1020': ['J86-3001'],
#  'A94-1021': [],
#  'A94-1022': ['C88-2121',
#   'H91-1033',
#   'H91-1034',
#   'H91-1042',
#   'H92-1061',
#   'H93-1007',
#   'P93-1008'],
#  'A94-1023': [],
#  'A94-1024': ['A88-1019',
#   'A92-1021',
#   'C90-3030',
#   'C92-1027',
#   'C94-1081',
#   'E93-1046',
#   'E93-1066'],
#  'A94-1025': ['C92-4204'],
#  'A94-1026': [],
#  'A94-1027': ['A92-1018'],
#  'A94-1028': ['C92-1033', 'H93-1070', 'H93-1071', 'W93-0302'],
#  'A94-1029': ['A88-1018', 'A88-1019', 'A92-1013'],
#  'A94-1030': ['P94-1010', 'P94-1012', 'W93-0305'],
#  'A94-1031': ['J90-1003', 'P94-1049', 'W93-0308'],
#  'A94-1032': ['A92-1028', 'C92-2088'],
#  'A94-1033': ['J90-1003', 'P94-1049', 'W93-0308'],
#  'A94-1034': [],
#  'A94-1035': [],
#  'A94-1036': [],
#  'A94-1037': ['E93-1066'],
#  'A94-1038': ['C92-2097', 'P91-1024'],
#  'A94-1039': ['C94-1030'],
#  'A94-1040': ['C90-3010'],
#  'A94-1041': ['C90-3018', 'C92-2093', 'C92-2096'],
#  'A94-1042': ['C92-3140'],
#  'A94-1043': [],
#  'A94-1044': ['W90-0108'],
#  'A94-1045': ['E89-1009', 'M93-1026'],
#  'A94-1046': ['C92-1010', 'E93-1067'],
#  'A94-1047': ['C86-1132', 'C90-1021'],
#  'A97-1001': ['P93-1008', 'P94-1016'],
#  'A97-1002': [],
#  'A97-1003': ['A94-1013'],
#  'A97-1004': ['A92-1018',
#   'A94-1013',
#   'H89-2048',
#   'J93-2004',
#   'J97-2002',
#   'P96-1025',
#   'W96-0213'],
#  'A97-1005': [],
#  'A97-1006': ['A97-1031', 'C94-1072', 'C96-2120', 'W96-0411'],
#  'A97-1007': [],
#  'A97-1008': ['J95-3001', 'J95-4001', 'P89-1016', 'P92-1025'],
#  'A97-1009': ['J91-3001', 'J94-3001'],
#  'A97-1010': ['C92-1019',
#   'C96-1039',
#   'H93-1066',
#   'P83-1019',
#   'P92-1008',
#   'P94-1010',
#   'P94-1041'],
#  'A97-1011': ['C90-3030', 'C94-1092', 'C94-1104', 'C96-1058', 'C96-1096'],
#  'A97-1012': ['C92-1027', 'E93-1046', 'E95-1021', 'P96-1015'],
#  'A97-1013': ['A94-1008',
#   'C90-3030',
#   'C92-2070',
#   'C94-1027',
#   'C96-2148',
#   'E95-1021',
#   'E95-1029',
#   'P89-1015',
#   'W95-0101',
#   'W96-0102'],
#  'A97-1014': ['A92-1018', 'C96-1020', 'C96-2120', 'H94-1020', 'P95-1024'],
#  'A97-1015': ['C94-2174', 'H91-1060', 'J93-2001', 'J93-2004', 'W96-0209'],
#  'A97-1016': ['C86-1069', 'C96-1018', 'C96-2198', 'P94-1039', 'P96-1022'],
#  'A97-1017': ['A92-1018', 'A92-1021', 'J93-2004', 'J94-2001'],
#  'A97-1018': ['C92-1019', 'C92-4199', 'P94-1010', 'W93-0305'],
#  'A97-1019': ['A94-1001', 'C96-2171', 'P94-1001'],
#  'A97-1020': ['C96-2140'],
#  'A97-1021': ['C96-1055', 'J90-1003', 'J93-2002'],
#  'A97-1022': ['C94-2146', 'C96-2131', 'J83-3001'],
#  'A97-1023': ['A97-1022'],
#  'A97-1024': ['H93-1025',
#   'J80-1003',
#   'J89-1003',
#   'J90-4001',
#   'J94-4002',
#   'P90-1018'],
#  'A97-1025': ['J92-1001', 'P94-1013', 'P96-1010', 'W95-0104'],
#  'A97-1026': ['J93-1007', 'P89-1010', 'W96-0304'],
#  'A97-1027': ['A94-1025', 'C92-4204', 'C96-1083'],
#  'A97-1028': ['M93-1007', 'M95-1002', 'X96-1049', 'X96-1050'],
#  'A97-1029': ['A88-1019',
#   'H94-1053',
#   'J93-2006',
#   'M95-1006',
#   'M95-1012',
#   'M95-1019'],
#  'A97-1030': ['J87-3005',
#   'J93-1005',
#   'M92-1035',
#   'P92-1003',
#   'W93-0104',
#   'W93-0105',
#   'W93-0114'],
#  'A97-1031': ['A92-1024',
#   'A97-1006',
#   'C92-1008',
#   'C94-2144',
#   'C96-1011',
#   'C96-1079',
#   'J93-3001',
#   'M93-1009',
#   'M95-1014',
#   'P93-1008',
#   'W95-0101'],
#  'A97-1032': ['E95-1027'],
#  'A97-1033': ['A88-1019',
#   'H93-1062',
#   'M92-1024',
#   'M92-1030',
#   'M92-1031',
#   'M92-1032',
#   'M93-1010',
#   'M93-1023',
#   'W93-0104',
#   'W93-0105',
#   'W96-0512'],
#  'A97-1034': ['A97-1054', 'E95-1027'],
#  'A97-1035': ['A97-1034',
#   'A97-1036',
#   'C96-1079',
#   'C96-1082',
#   'C96-2187',
#   'M95-1017'],
#  'A97-1036': ['C82-1004',
#   'C92-2123',
#   'C94-1019',
#   'C94-1070',
#   'H94-1026',
#   'P96-1027'],
#  'A97-1037': ['A97-1039', 'W96-0503'],
#  'A97-1038': ['A92-1006', 'J88-3006', 'P83-1022', 'W96-0401', 'W96-0416'],
#  'A97-1039': ['A92-1006',
#   'A97-1037',
#   'C92-3158',
#   'W94-0319',
#   'W96-0501',
#   'W96-0507'],
#  'A97-1040': ['A92-1021', 'A94-1001', 'C90-1014', 'M93-1003'],
#  'A97-1041': ['A94-1002', 'P88-1023', 'P95-1053'],
#  'A97-1042': [],
#  'A97-1043': ['A92-1021',
#   'C92-2070',
#   'C94-1049',
#   'C96-1069',
#   'C96-2134',
#   'C96-2166',
#   'P91-1034'],
#  'A97-1044': ['H93-1070'],
#  'A97-1045': ['J90-1003', 'J93-1007', 'W95-0111'],
#  'A97-1046': ['C92-1033',
#   'J92-4003',
#   'J93-2005',
#   'P92-1014',
#   'P94-1052',
#   'P95-1007',
#   'P96-1003',
#   'W93-0307'],
#  'A97-1047': ['C86-1152', 'J85-2005', 'W96-0409'],
#  'A97-1048': ['C80-1064',
#   'C90-2045',
#   'C90-3048',
#   'C90-3074',
#   'C94-2136',
#   'P84-1102'],
#  'A97-1049': ['M95-1018', 'X96-1054'],
#  'A97-1050': ['A94-1006',
#   'E95-1010',
#   'H91-1026',
#   'J93-1007',
#   'J93-2003',
#   'J96-1001',
#   'J96-2004',
#   'P93-1001',
#   'P93-1002',
#   'W93-0301',
#   'W95-0115',
#   'W96-0201'],
#  'A97-1051': ['A92-1021', 'C96-1047', 'C96-1079', 'H93-1029', 'X96-1053'],
#  'A97-1052': ['A92-1022',
#   'A94-1009',
#   'C92-2066',
#   'C92-2099',
#   'C94-1042',
#   'C94-2123',
#   'J87-3002',
#   'J93-1002',
#   'J93-2002',
#   'P87-1027',
#   'P90-1031',
#   'P91-1027',
#   'P93-1032',
#   'P94-1040',
#   'W93-0108',
#   'W93-0109',
#   'W96-0209'],
#  'A97-1053': ['C96-1004',
#   'H93-1054',
#   'J93-1003',
#   'J96-1002',
#   'P93-1005',
#   'P95-1037',
#   'P96-1025',
#   'W97-0123'],
#  'A97-1054': ['A97-1034', 'E95-1027', 'J93-1007'],
#  'A97-1055': ['A92-1013',
#   'C92-2070',
#   'C94-2113',
#   'C94-2119',
#   'C94-2195',
#   'C96-1005',
#   'C96-1038',
#   'J96-4006',
#   'P93-1024',
#   'P94-1038',
#   'W93-0106',
#   'W95-0105'],
#  'A97-1056': ['H93-1051',
#   'H93-1052',
#   'H94-1047',
#   'J96-1002',
#   'P91-1017',
#   'P91-1034',
#   'P94-1020',
#   'P96-1006',
#   'W96-0208',
#   'W96-0210'],
#  'A97-2001': [],
#  'A97-2002': [],
#  'A97-2003': ['A97-1006', 'A97-1031'],
#  'A97-2004': [],
#  'A97-2005': ['A97-1011'],
#  'A97-2006': ['C90-3044', 'C96-2178'],
#  'A97-2007': [],
#  'A97-2008': [],
#  'A97-2010': ['C92-2070', 'J93-1003', 'P94-1020', 'P95-1026', 'P96-1006'],
#  'A97-2011': [],
#  'A97-2012': [],
#  'A97-2013': [],
#  'A97-2014': [],
#  'A97-2015': [],
#  'A97-2016': ['A97-1014', 'C96-1020', 'H94-1020'],
#  'A97-2017': ['A97-1035', 'M95-1017'],
#  'A97-2018': [],
#  'A97-2019': ['H93-1006', 'H93-1060'],
#  'A97-2020': [],
#  'A97-2021': [],
#  'C00-1001': ['C90-2064', 'C94-1066', 'P99-1033', 'P99-1034'],
#  'C00-1002': ['C96-1064', 'P93-1024', 'P99-1014'],
#  'C00-1003': [],
#  'C00-1004': ['A92-1018', 'J95-4004', 'P97-1030'],
#  'C00-1005': ['C88-1010', 'P88-1024'],
#  'C00-1006': ['C92-4203', 'C94-1101', 'W99-0902'],
#  'C00-1007': ['A00-2023',
#   'A00-2026',
#   'A92-1006',
#   'J99-2004',
#   'P85-1012',
#   'P98-1006',
#   'P98-1116',
#   'W00-1401',
#   'W94-0319',
#   'W98-1426'],
#  'C00-1008': ['E93-1043', 'J94-3010', 'J97-4003', 'P91-1027', 'P98-1014'],
#  'C00-1009': ['J91-3004', 'J93-2004', 'P92-1017', 'P98-1035'],
#  'C00-1010': ['A00-2021',
#   'C00-1011',
#   'E95-1038',
#   'H91-1060',
#   'H94-1020',
#   'P97-1021',
#   'P98-1022',
#   'P99-1069'],
#  'C00-1011': ['A00-2018',
#   'C00-1010',
#   'C92-3126',
#   'C96-2215',
#   'E91-1004',
#   'E93-1006',
#   'H90-1053',
#   'H91-1060',
#   'J93-1002',
#   'J93-2004',
#   'J93-2006',
#   'J98-2004',
#   'P97-1003',
#   'P97-1021',
#   'P98-1022',
#   'W96-0111'],
#  'C00-1012': ['C96-1021',
#   'E99-1011',
#   'J91-1002',
#   'P94-1002',
#   'P94-1008',
#   'W97-0707',
#   'W97-0711',
#   'W98-1123',
#   'W99-0301'],
#  'C00-1013': [],
#  'C00-1014': ['C94-1091', 'C96-1023', 'P98-1023'],
#  'C00-1015': ['W95-0115', 'W99-0602'],
#  'C00-1016': ['C86-1156',
#   'C88-1026',
#   'C88-1060',
#   'C90-3022',
#   'E91-1008',
#   'E95-1002',
#   'E95-1025',
#   'P89-1032'],
#  'C00-1017': ['E99-1016',
#   'J93-2004',
#   'J98-4004',
#   'P96-1025',
#   'P99-1054',
#   'W97-0301',
#   'W98-1115'],
#  'C00-1018': ['C96-2120', 'P94-1026', 'P96-1030', 'P99-1035'],
#  'C00-1019': ['J90-2002'],
#  'C00-1020': ['C90-2067',
#   'H93-1051',
#   'J98-1001',
#   'P95-1026',
#   'P96-1006',
#   'P98-1051',
#   'P98-2228',
#   'W97-0213',
#   'W97-0810'],
#  'C00-1021': ['A97-1017'],
#  'C00-1022': ['C92-2070',
#   'C96-2161',
#   'E99-1003',
#   'J98-1001',
#   'P97-1066',
#   'W97-0803'],
#  'C00-1023': ['C92-2070',
#   'C96-1005',
#   'H93-1061',
#   'P95-1026',
#   'P96-1006',
#   'P97-1003',
#   'W97-0209',
#   'W97-0213',
#   'W98-0701',
#   'W98-0703'],
#  'C00-1024': ['C96-1039', 'J98-3005', 'M98-1017', 'P98-1036', 'P99-1028'],
#  'C00-1025': ['A97-1032', 'E95-1027', 'P99-1057'],
#  'C00-1026': ['C92-1019', 'J98-1001'],
#  'C00-1027': ['P99-1022'],
#  'C00-1028': ['W97-0209', 'W99-0901'],
#  'C00-1029': ['C92-2070',
#   'C94-2195',
#   'E95-1016',
#   'H94-1048',
#   'J93-1003',
#   'J93-1005',
#   'J98-2002',
#   'P96-1025',
#   'P97-1003',
#   'P97-1056',
#   'P98-2177',
#   'W95-0103',
#   'W97-0109',
#   'W99-0631'],
#  'C00-1030': ['A97-1029', 'E99-1043', 'M93-1007', 'P96-1041', 'W98-1118'],
#  'C00-1031': ['J81-4001',
#   'J86-3001',
#   'J94-4002',
#   'J95-2003',
#   'P98-1011',
#   'P98-1044',
#   'P98-1090',
#   'W97-1303',
#   'W97-1307',
#   'W98-1119',
#   'W99-0307'],
#  'C00-1032': ['A92-1021', 'C92-3150', 'J97-3003', 'P98-1092', 'P99-1044'],
#  'C00-1033': ['P98-2173', 'W98-1427'],
#  'C00-1034': ['E99-1023',
#   'J93-2004',
#   'P98-1010',
#   'P98-1034',
#   'W95-0107',
#   'W97-1013',
#   'W99-0621',
#   'W99-0629'],
#  'C00-1035': ['J93-2004', 'P98-1081', 'W96-0214'],
#  'C00-1036': ['C96-1043', 'P98-2173', 'W00-1404'],
#  'C00-1037': [],
#  'C00-1038': ['C94-2163',
#   'J94-3001',
#   'J97-2003',
#   'J98-2006',
#   'P97-1040',
#   'W98-0904'],
#  'C00-1039': ['J96-2004', 'P98-1112', 'P99-1051', 'P99-1071'],
#  'C00-1040': ['A00-2043',
#   'C92-1035',
#   'C92-4171',
#   'E93-1047',
#   'J99-3001',
#   'P84-1024',
#   'P85-1022',
#   'P88-1011',
#   'P89-1005'],
#  'C00-1041': ['A97-1017', 'C00-1021', 'H94-1020', 'J93-2004'],
#  'C00-1042': ['A88-1019',
#   'A92-1018',
#   'A94-1024',
#   'J95-3004',
#   'J95-4004',
#   'P97-1029',
#   'P98-1063',
#   'P98-1080',
#   'P99-1033',
#   'W95-0101',
#   'W96-0207',
#   'W99-0633'],
#  'C00-1043': ['J86-3006', 'P96-1025'],
#  'C00-1044': ['A88-1019', 'J93-2004', 'P97-1023', 'P99-1032'],
#  'C00-1045': ['J95-2003', 'J99-3001', 'P98-2204', 'W99-0108'],
#  'C00-1046': ['A88-1019',
#   'A92-1021',
#   'J95-4004',
#   'P96-1043',
#   'P97-1030',
#   'W95-0101'],
#  'C00-1047': ['C94-1084', 'J90-1003', 'J93-1003', 'W99-0609'],
#  'C00-1048': ['J95-2004', 'J95-4004'],
#  'C00-1049': ['J91-1002', 'P99-1057'],
#  'C00-1050': ['W97-0504', 'W97-0505'],
#  'C00-1051': ['A00-2009',
#   'A94-1016',
#   'E99-1026',
#   'P96-1025',
#   'P97-1003',
#   'P98-1029',
#   'P98-1081',
#   'W99-0623'],
#  'C00-1052': ['A00-2033',
#   'C92-1032',
#   'J97-3004',
#   'J98-4004',
#   'P97-1003',
#   'P98-1101',
#   'P99-1054',
#   'P99-1070'],
#  'C00-1053': ['C00-1054', 'P93-1029', 'P97-1036', 'P98-1102'],
#  'C00-1054': ['J94-3001',
#   'J97-2003',
#   'P97-1036',
#   'P98-1101',
#   'P98-1102',
#   'W00-0508'],
#  'C00-1055': ['A97-1004', 'J95-4004', 'P97-1003', 'P98-2160'],
#  'C00-1056': ['C94-2210',
#   'C96-1041',
#   'J92-4003',
#   'J93-2003',
#   'J94-2001',
#   'P97-1017'],
#  'C00-1057': ['C00-2119', 'C94-1032', 'P98-1068', 'P98-2180'],
#  'C00-1058': ['A94-1006',
#   'C94-1084',
#   'C94-1100',
#   'C96-2130',
#   'E93-1015',
#   'H91-1026',
#   'J93-1003',
#   'J96-1001',
#   'P93-1003',
#   'P95-1032'],
#  'C00-1059': ['C92-2082', 'C94-2139', 'J90-1003', 'J93-1003'],
#  'C00-1060': ['C00-2110',
#   'C92-2066',
#   'E99-1026',
#   'J93-1002',
#   'J96-1002',
#   'P98-1083',
#   'P98-2144',
#   'W97-0301',
#   'W98-1114'],
#  'C00-1061': ['J96-1002', 'P97-1017'],
#  'C00-1062': ['E95-1007', 'J99-2006', 'W91-0104'],
#  'C00-1063': ['A97-1052', 'J94-4001', 'P93-1032', 'P98-2214'],
#  'C00-1064': ['H94-1028', 'J90-2002', 'J93-2003', 'J96-1002'],
#  'C00-1065': [],
#  'C00-1066': ['J98-1002', 'P97-1006'],
#  'C00-1067': ['P00-1047', 'P83-1020', 'P94-1023', 'P95-1021', 'P98-1058'],
#  'C00-1068': ['P99-1040'],
#  'C00-1069': ['A97-1017'],
#  'C00-1070': ['W96-0213', 'W99-0615'],
#  'C00-1071': [],
#  'C00-1072': ['J90-1003', 'J93-1003', 'J97-1003'],
#  'C00-1073': ['P98-2219'],
#  'C00-1074': ['C94-1027', 'J94-2001', 'J95-4004', 'P98-2132'],
#  'C00-1075': ['A94-1016',
#   'C90-3101',
#   'C92-2101',
#   'C92-2107',
#   'C94-1003',
#   'C94-1014',
#   'C96-1070',
#   'J94-4004',
#   'J96-1003'],
#  'C00-1076': ['J86-3001', 'J92-4007', 'J96-3006', 'J98-4001'],
#  'C00-1077': ['A92-1021', 'C92-3150', 'C94-1084', 'C96-2212', 'W95-0105'],
#  'C00-1078': ['C96-1078',
#   'J93-2003',
#   'J98-2004',
#   'P93-1004',
#   'P98-2139',
#   'W98-1115'],
#  'C00-1079': ['C90-2043', 'C90-2057'],
#  'C00-1080': ['P83-1021', 'P94-1035', 'P97-1001'],
#  'C00-1081': ['A88-1019',
#   'A92-1018',
#   'C96-1058',
#   'H89-2014',
#   'J94-2001',
#   'J95-2001',
#   'P96-1025',
#   'P97-1003',
#   'P98-1035',
#   'P98-1083',
#   'P98-2148',
#   'P99-1033'],
#  'C00-1082': ['E99-1023',
#   'E99-1026',
#   'J96-1002',
#   'P94-1013',
#   'W95-0107',
#   'W96-0213',
#   'W97-0301',
#   'W98-1118'],
#  'C00-1083': ['J86-3001', 'P99-1024'],
#  'C00-1084': ['C94-1101', 'C94-2167', 'C96-2099', 'P89-1010', 'P98-1010'],
#  'C00-1085': ['A97-1052', 'J97-4005', 'P99-1069'],
#  'C00-2086': ['A94-1007', 'J94-4001', 'P92-1003', 'P96-1011'],
#  'C00-2087': ['J92-4004', 'P95-1021', 'P98-1058'],
#  'C00-2088': ['W98-0608'],
#  'C00-2089': ['A88-1019',
#   'A88-1030',
#   'A92-1018',
#   'A97-1012',
#   'A97-1013',
#   'C92-3150',
#   'E95-1022',
#   'J93-2004',
#   'J93-2006',
#   'J94-2001',
#   'J95-4004',
#   'P98-1010',
#   'P98-1029',
#   'P98-1034',
#   'P98-1081',
#   'W93-0306',
#   'W95-0107',
#   'W96-0102',
#   'W96-0213',
#   'W99-0707'],
#  'C00-2090': ['J93-1004', 'P98-1121'],
#  'C00-2091': [],
#  'C00-2092': ['C90-3001', 'C90-3045', 'C96-2215', 'J90-2002'],
#  'C00-2093': ['W98-1411'],
#  'C00-2094': ['J94-4003', 'P95-1026', 'P99-1014', 'W97-0209'],
#  'C00-2095': ['C94-1071', 'J96-3004', 'J97-2002', 'J97-4004'],
#  'C00-2096': ['J94-2005'],
#  'C00-2097': ['A97-1001', 'P99-1024'],
#  'C00-2098': ['J93-1002', 'P99-1061', 'W96-0209'],
#  'C00-2099': ['A97-1011',
#   'C96-2215',
#   'P93-1005',
#   'P95-1037',
#   'P96-1023',
#   'P97-1003'],
#  'C00-2100': ['A97-1052',
#   'E99-1007',
#   'J93-1003',
#   'J93-2002',
#   'P89-1022',
#   'P91-1027',
#   'P93-1032',
#   'P98-1080',
#   'P99-1051',
#   'W93-0109',
#   'W98-1114',
#   'W99-0503',
#   'W99-0632'],
#  'C00-2101': ['M92-1021', 'P99-1062', 'W97-1002'],
#  'C00-2102': ['P94-1013',
#   'W95-0107',
#   'W98-1120',
#   'W99-0612',
#   'W99-0613',
#   'X96-1050'],
#  'C00-2103': ['C96-1054', 'E95-1001', 'P98-1024', 'P98-2193'],
#  'C00-2104': ['C96-2157',
#   'J93-1007',
#   'P89-1010',
#   'P90-1034',
#   'P93-1023',
#   'P93-1024',
#   'P98-2182',
#   'P99-1016',
#   'W97-0313',
#   'W97-0703',
#   'W99-0212',
#   'W99-0609'],
#  'C00-2105': ['A88-1019',
#   'E99-1016',
#   'P96-1024',
#   'P97-1003',
#   'P98-1035',
#   'P99-1035',
#   'P99-1059',
#   'W93-0306',
#   'W95-0107'],
#  'C00-2106': ['E93-1004', 'P83-1021', 'P89-1017'],
#  'C00-2107': ['C96-1059', 'J98-3002', 'J99-1001'],
#  'C00-2108': ['C94-2123',
#   'C96-1055',
#   'E95-1016',
#   'E99-1007',
#   'P98-1112',
#   'P99-1051',
#   'W97-0209'],
#  'C00-2109': ['E99-1026', 'P95-1037', 'P97-1003', 'P98-1083', 'W97-0301'],
#  'C00-2110': ['C00-1060', 'C00-2109', 'C94-1071', 'P98-1083'],
#  'C00-2111': ['C80-1064',
#   'C82-1004',
#   'C90-2045',
#   'C92-3129',
#   'C92-3168',
#   'C94-1017'],
#  'C00-2112': ['J86-3001', 'J95-2003'],
#  'C00-2113': ['C90-3001',
#   'C96-1089',
#   'J93-1007',
#   'P96-1020',
#   'P97-1061',
#   'P98-1010',
#   'W95-0107'],
#  'C00-2114': [],
#  'C00-2115': ['C96-1005', 'C96-1086', 'J91-1002', 'P91-1023', 'W95-0105'],
#  'C00-2116': ['C94-1101', 'C96-2208', 'J97-2002', 'P95-1037', 'W98-1104'],
#  'C00-2117': ['C94-2174', 'E99-1021', 'J93-2001', 'P97-1005'],
#  'C00-2118': ['A00-2034',
#   'A97-1052',
#   'C96-1055',
#   'E99-1007',
#   'J93-2002',
#   'P89-1022',
#   'P93-1032',
#   'P97-1003',
#   'P98-1046',
#   'W99-0503',
#   'W99-0632'],
#  'C00-2119': ['C00-1057',
#   'C94-1032',
#   'P98-1068',
#   'P98-2180',
#   'T75-2001',
#   'W97-0908'],
#  'C00-2120': [],
#  'C00-2121': ['J92-4003', 'J93-1007', 'J96-2003'],
#  'C00-2122': ['A94-1016', 'P98-1060', 'W99-0604'],
#  'C00-2123': ['C00-2163', 'J93-2003', 'P97-1037', 'W99-0604'],
#  'C00-2124': ['A00-2007',
#   'C00-1034',
#   'J93-2004',
#   'J96-1002',
#   'P98-1029',
#   'P98-1081',
#   'W95-0107',
#   'W99-0621'],
#  'C00-2125': ['J99-4003', 'P83-1019'],
#  'C00-2126': ['J96-1002', 'P99-1018'],
#  'C00-2127': ['C96-2166', 'P98-2151', 'W00-0407', 'W97-0702'],
#  'C00-2128': ['C88-1036',
#   'C90-2008',
#   'C92-2082',
#   'C96-1025',
#   'J90-1003',
#   'J92-4003',
#   'P92-1047',
#   'P96-1048',
#   'P99-1008',
#   'P99-1062',
#   'W99-0205'],
#  'C00-2129': ['P98-1012', 'P98-2151', 'P99-1071', 'W99-0211'],
#  'C00-2130': ['E99-1001',
#   'J86-3001',
#   'J96-2004',
#   'J97-1003',
#   'J98-2001',
#   'M95-1019',
#   'M98-1007',
#   'P99-1047',
#   'P99-1048'],
#  'C00-2131': ['C90-3044',
#   'C92-2101',
#   'C92-2115',
#   'C96-1078',
#   'C96-2211',
#   'J80-1003',
#   'J94-4001',
#   'P93-1004',
#   'P96-1020',
#   'P98-2223'],
#  'C00-2132': ['C96-2211',
#   'P95-1037',
#   'P96-1020',
#   'P96-1025',
#   'P97-1003',
#   'P98-2223'],
#  'C00-2133': ['E99-1006',
#   'J95-2003',
#   'P87-1022',
#   'P89-1007',
#   'P95-1040',
#   'P98-2204',
#   'P98-2241'],
#  'C00-2134': ['C94-1015', 'C96-1030', 'P96-1023', 'P98-1061'],
#  'C00-2135': ['A00-2018',
#   'P91-1022',
#   'P93-1004',
#   'P97-1003',
#   'W93-0301',
#   'W95-0115',
#   'W96-0107',
#   'W97-0301'],
#  'C00-2136': ['A00-1039',
#   'A97-1011',
#   'M92-1021',
#   'M95-1011',
#   'M95-1014',
#   'M98-1009',
#   'M98-1011'],
#  'C00-2137': ['J93-1001', 'J93-3001'],
#  'C00-2138': ['J95-2004', 'J97-2003', 'P94-1010', 'P96-1025', 'W95-0107'],
#  'C00-2139': ['P97-1021'],
#  'C00-2140': ['A00-1043',
#   'A00-2025',
#   'A97-1003',
#   'J97-1003',
#   'P98-2237',
#   'W97-0702',
#   'W97-0703',
#   'W98-1421'],
#  'C00-2141': ['A88-1019',
#   'P95-1037',
#   'P96-1025',
#   'W93-0306',
#   'W95-0103',
#   'W97-0104',
#   'W97-0301'],
#  'C00-2142': ['C88-2132', 'C96-2188', 'J92-2002', 'W98-1310'],
#  'C00-2143': ['J93-2004'],
#  'C00-2144': [],
#  'C00-2145': ['C90-3044', 'J90-2002'],
#  'C00-2146': ['H91-1044',
#   'H91-1060',
#   'J93-1005',
#   'P92-1006',
#   'P96-1025',
#   'W98-1110'],
#  'C00-2147': ['X96-1056'],
#  'C00-2148': ['C96-1034', 'J88-2003', 'P97-1026', 'P98-1046', 'W97-0204'],
#  'C00-2149': ['J93-4001', 'P89-1018', 'P97-1050', 'P98-1060'],
#  'C00-2150': [],
#  'C00-2151': ['C90-3051', 'P92-1041', 'P98-1086', 'W98-0509'],
#  'C00-2152': ['C90-3044', 'C92-2115', 'C96-1070', 'P98-2223'],
#  'C00-2153': [],
#  'C00-2154': ['C67-1009', 'C96-1030', 'W97-0412'],
#  'C00-2155': ['P85-1018', 'P99-1061'],
#  'C00-2156': ['A92-1021', 'J94-3007', 'W98-1110'],
#  'C00-2157': ['A97-1014', 'J93-2004', 'P99-1035'],
#  'C00-2158': [],
#  'C00-2159': [],
#  'C00-2160': [],
#  'C00-2161': [],
#  'C00-2162': ['C90-3030',
#   'J93-2003',
#   'P97-1047',
#   'P98-2158',
#   'P98-2162',
#   'W99-0604'],
#  'C00-2163': ['C96-2141', 'J93-2003', 'W99-0604'],
#  'C00-2164': ['W94-0319'],
#  'C00-2165': ['J95-2004'],
#  'C00-2166': ['C96-1024', 'C96-1054', 'P98-1024'],
#  'C00-2167': [],
#  'C00-2168': ['H90-1055', 'J90-2002'],
#  'C00-2169': ['J90-2002', 'P83-1019', 'P92-1008', 'P93-1007'],
#  'C00-2170': [],
#  'C00-2171': ['J96-2002'],
#  'C00-2172': ['C90-3044', 'C96-1030', 'W99-0604'],
#  'C00-2173': [],
#  'C00-2174': ['W96-0411'],
#  'C00-2175': ['C94-2195', 'J93-2004', 'W99-0629', 'W99-0706'],
#  'C02-1001': ['C90-2040', 'J94-3001', 'J97-2003'],
#  'C02-1002': ['H91-1026',
#   'J93-1004',
#   'J93-1006',
#   'J93-2003',
#   'J96-1001',
#   'P93-1003',
#   'P98-1050',
#   'W02-0808'],
#  'C02-1003': ['J00-2004', 'J93-2004', 'J97-3002', 'P95-1033', 'P97-1003'],
#  'C02-1004': ['C94-2195',
#   'J93-1005',
#   'P00-1014',
#   'P98-2177',
#   'W95-0103',
#   'W97-0109'],
#  'C02-1005': ['A00-2026',
#   'C00-1007',
#   'C88-2150',
#   'N01-1001',
#   'P95-1034',
#   'P98-1116',
#   'P99-1018'],
#  'C02-1006': ['C00-1024', 'P00-1039', 'P01-1064'],
#  'C02-1007': ['J93-1003',
#   'J93-1007',
#   'P98-2127',
#   'P99-1008',
#   'P99-1067',
#   'W93-0113',
#   'W93-0310'],
#  'C02-1008': ['C00-1015',
#   'J93-2003',
#   'J96-1001',
#   'P98-1069',
#   'P99-1067',
#   'W93-0301'],
#  'C02-1009': ['C00-2163',
#   'C96-2141',
#   'J93-2003',
#   'P91-1017',
#   'P91-1022',
#   'P91-1023',
#   'P93-1001',
#   'P93-1002',
#   'P94-1012'],
#  'C02-1010': ['C00-2131',
#   'C92-2101',
#   'C96-1078',
#   'J97-3002',
#   'P00-1015',
#   'P00-1050',
#   'P93-1004',
#   'P98-2221',
#   'W00-0726'],
#  'C02-1011': ['A00-2009',
#   'C96-2098',
#   'J93-2003',
#   'P00-1015',
#   'P00-1054',
#   'P98-1069',
#   'P99-1067',
#   'W01-1413',
#   'W99-0905'],
#  'C02-1012': ['J92-4003', 'W98-1120'],
#  'C02-1013': ['A00-2022',
#   'A00-2031',
#   'A00-2034',
#   'A97-1052',
#   'J93-2002',
#   'N01-1013',
#   'P00-1014',
#   'P00-1017',
#   'P01-1060',
#   'P98-1010',
#   'P99-1041',
#   'P99-1061',
#   'W97-0307',
#   'W97-0810',
#   'W98-1114',
#   'W99-0629'],
#  'C02-1014': ['C73-1027'],
#  'C02-1015': ['J00-3005',
#   'P00-1012',
#   'P95-1018',
#   'P98-2199',
#   'P99-1018',
#   'W00-1434',
#   'W98-1415'],
#  'C02-1016': ['A00-2038',
#   'J00-2004',
#   'J93-1003',
#   'J94-3004',
#   'J99-1003',
#   'N01-1014',
#   'N01-1020',
#   'W01-0504',
#   'W97-0311',
#   'W99-0626'],
#  'C02-1017': ['C00-1014',
#   'C00-2135',
#   'C92-2101',
#   'C94-1091',
#   'C96-1023',
#   'C96-1078',
#   'P91-1024',
#   'P93-1004',
#   'W01-1401'],
#  'C02-1018': ['W00-0403'],
#  'C02-1019': ['P98-2125'],
#  'C02-1020': ['C96-1006',
#   'C96-2098',
#   'H91-1026',
#   'J93-1006',
#   'P97-1063',
#   'P98-2191',
#   'W00-0730',
#   'W00-1303',
#   'W96-0107',
#   'W97-0119'],
#  'C02-1021': ['A00-1031', 'A97-1014', 'C00-1046'],
#  'C02-1022': ['J91-1003', 'J91-4003', 'P93-1012'],
#  'C02-1023': [],
#  'C02-1024': ['J83-2002', 'J99-4004', 'P01-1061', 'P89-1018', 'P94-1016'],
#  'C02-1025': ['A97-1029',
#   'E99-1001',
#   'M95-1018',
#   'M98-1009',
#   'M98-1021',
#   'M98-1028'],
#  'C02-1026': ['A00-1023', 'A00-1041', 'C02-1042', 'W01-1203'],
#  'C02-1027': ['E95-1022', 'P98-2143'],
#  'C02-1028': ['P92-1018'],
#  'C02-1029': ['E95-1012',
#   'J97-4005',
#   'P00-1061',
#   'P01-1060',
#   'P02-1035',
#   'P89-1018',
#   'P99-1069'],
#  'C02-1030': ['P99-1065'],
#  'C02-1031': [],
#  'C02-1032': ['C00-2163',
#   'E99-1010',
#   'J93-2003',
#   'J96-1002',
#   'P01-1027',
#   'W00-0707'],
#  'C02-1033': ['A00-2004',
#   'J90-1003',
#   'J97-1003',
#   'J97-1005',
#   'P01-1064',
#   'P93-1041',
#   'P98-1100',
#   'P98-2243',
#   'P99-1077',
#   'W01-0514',
#   'W98-1123'],
#  'C02-1034': [],
#  'C02-1035': ['H94-1052', 'J86-3001', 'P97-1036', 'P98-1102'],
#  'C02-1036': [],
#  'C02-1037': [],
#  'C02-1038': ['C96-1005', 'H92-1045'],
#  'C02-1039': ['J01-3001',
#   'J95-4004',
#   'J98-1006',
#   'J99-2002',
#   'N01-1011',
#   'P96-1006',
#   'W96-0208',
#   'W96-0211'],
#  'C02-1040': ['A97-1052',
#   'C00-2100',
#   'C00-2108',
#   'C02-1132',
#   'E99-1007',
#   'J01-3003',
#   'J93-1003',
#   'P93-1032',
#   'P98-2247',
#   'P99-1051',
#   'W00-1325',
#   'W93-0109',
#   'W96-0213',
#   'W99-0503',
#   'W99-0632'],
#  'C02-1041': ['P91-1024'],
#  'C02-1042': ['A00-1023', 'A00-1041', 'C02-1026', 'P02-1006', 'W01-1203'],
#  'C02-1043': ['J00-4003', 'P00-1012', 'P99-1018'],
#  'C02-1044': ['C96-1005', 'J98-1003', 'W00-1104', 'W00-1202', 'W00-1318'],
#  'C02-1045': [],
#  'C02-1046': ['C00-2094',
#   'J90-2002',
#   'J94-4003',
#   'J95-4004',
#   'P97-1007',
#   'W01-0504',
#   'W99-0707'],
#  'C02-1047': [],
#  'C02-1048': ['J83-3001', 'W96-0406', 'W98-0210'],
#  'C02-1049': ['C00-1027',
#   'C92-1019',
#   'J93-1001',
#   'J93-1007',
#   'J96-1001',
#   'J96-3004'],
#  'C02-1050': ['C00-2123',
#   'J93-2003',
#   'J99-4005',
#   'P01-1030',
#   'P97-1047',
#   'W01-1408'],
#  'C02-1051': ['J95-2003'],
#  'C02-1052': ['C94-1002', 'J99-4002'],
#  'C02-1053': ['C00-2167',
#   'C96-2166',
#   'N01-1025',
#   'P01-1041',
#   'P98-1009',
#   'W00-1303'],
#  'C02-1054': ['C00-2167', 'N01-1025', 'P01-1041', 'W98-1120'],
#  'C02-1055': ['J98-1001'],
#  'C02-1056': ['C02-1163'],
#  'C02-1057': ['C00-1055', 'H94-1019'],
#  'C02-1058': ['C00-1059',
#   'C92-2070',
#   'C96-2098',
#   'J94-4003',
#   'J98-1001',
#   'J98-1002',
#   'P91-1034',
#   'P95-1026',
#   'P95-1050',
#   'P98-1110',
#   'W97-0211'],
#  'C02-1059': ['P83-1019', 'P92-1008', 'P93-1007', 'P99-1053'],
#  'C02-1060': ['P90-1034',
#   'P93-1022',
#   'P94-1038',
#   'P97-1009',
#   'P98-2148',
#   'W96-0104'],
#  'C02-1061': [],
#  'C02-1062': [],
#  'C02-1063': ['E99-1019',
#   'J91-1002',
#   'J97-1003',
#   'J98-1004',
#   'P84-1062',
#   'P98-2127'],
#  'C02-1064': ['A00-2023',
#   'A00-2026',
#   'C00-1007',
#   'C00-2126',
#   'E99-1026',
#   'J90-2002',
#   'J96-1002',
#   'P95-1034',
#   'P98-1116',
#   'W01-0512',
#   'W01-0812',
#   'W98-1426'],
#  'C02-1065': ['C96-2098',
#   'J93-1003',
#   'J94-4003',
#   'P95-1032',
#   'P99-1067',
#   'W97-0119'],
#  'C02-1066': ['J89-4001', 'P83-1021'],
#  'C02-1067': ['C02-1095'],
#  'C02-1068': ['A00-2018',
#   'C00-2105',
#   'C00-2124',
#   'J98-4004',
#   'W00-0725',
#   'W00-0726',
#   'W00-0730',
#   'W01-0712'],
#  'C02-1069': [],
#  'C02-1070': ['C00-2136',
#   'H01-1035',
#   'J95-4004',
#   'N01-1006',
#   'P00-1035',
#   'P00-1056',
#   'P98-1067'],
#  'C02-1071': ['C00-2132',
#   'C96-1049',
#   'C96-2120',
#   'H92-1086',
#   'P01-1034',
#   'P02-1056',
#   'P98-2144',
#   'P98-2195'],
#  'C02-1072': [],
#  'C02-1073': ['A00-2024',
#   'A00-2035',
#   'P91-1023',
#   'W00-0401',
#   'W00-0403',
#   'W00-0408'],
#  'C02-1074': ['C00-1066'],
#  'C02-1075': ['C00-1085',
#   'C00-2155',
#   'E95-1012',
#   'J93-1002',
#   'J97-4005',
#   'P00-1061',
#   'P01-1022',
#   'P85-1018',
#   'P98-1022',
#   'P99-1069'],
#  'C02-1076': ['C96-1070', 'J93-2003', 'P00-1056', 'W01-1401'],
#  'C02-1077': ['A97-1052',
#   'C00-1085',
#   'J97-4005',
#   'P99-1069',
#   'W00-0709',
#   'W02-2018'],
#  'C02-1078': ['C96-1079',
#   'C96-2137',
#   'J95-2003',
#   'P86-1031',
#   'P95-1017',
#   'W98-1119'],
#  'C02-1079': ['H90-1053', 'H91-1042', 'J98-2004'],
#  'C02-1080': ['J96-3004',
#   'M98-1006',
#   'M98-1016',
#   'M98-1017',
#   'M98-1019',
#   'P01-1041',
#   'P97-1041',
#   'W99-0612'],
#  'C02-1081': ['C94-2174', 'E99-1019', 'W01-1607'],
#  'C02-1082': ['W02-0712'],
#  'C02-1083': ['C96-2212'],
#  'C02-1084': ['J94-4001', 'P01-1037', 'W00-1016'],
#  'C02-1085': ['A92-1021', 'P99-1071', 'W00-0403', 'W00-0405'],
#  'C02-1086': ['J90-1003', 'P99-1029'],
#  'C02-1087': ['W00-1104', 'W98-0705', 'W98-0706'],
#  'C02-1088': ['A97-1029',
#   'A97-1030',
#   'C00-2124',
#   'C00-2167',
#   'M98-1018',
#   'P00-1011',
#   'P00-1042',
#   'P95-1026',
#   'W99-0613'],
#  'C02-1089': [],
#  'C02-1090': ['P93-1024',
#   'P98-2127',
#   'P99-1004',
#   'P99-1016',
#   'W93-0106',
#   'W93-0113',
#   'W97-0803'],
#  'C02-1091': ['W97-0702'],
#  'C02-1092': ['C94-1035', 'C94-1087'],
#  'C02-1093': ['A00-1031',
#   'A00-1033',
#   'A97-1012',
#   'P02-1056',
#   'P97-1003',
#   'W97-0307'],
#  'C02-1094': ['J90-3003'],
#  'C02-1095': ['C00-2097', 'N01-1030', 'P01-1022'],
#  'C02-1096': ['J92-4003', 'P01-1025', 'W97-0506'],
#  'C02-1097': ['C96-1005',
#   'J98-1004',
#   'J98-4002',
#   'P91-1019',
#   'P95-1026',
#   'P97-1007',
#   'P98-1037'],
#  'C02-1098': ['C02-2006', 'P98-2151'],
#  'C02-1099': ['J90-2002', 'J96-4002', 'P97-1017'],
#  'C02-1100': ['C92-2072',
#   'E93-1027',
#   'J93-2004',
#   'J99-1002',
#   'P00-1058',
#   'P90-1021',
#   'P91-1028'],
#  'C02-1101': ['A00-2020',
#   'J01-2002',
#   'J95-4004',
#   'P02-1063',
#   'P98-2164',
#   'W96-0213',
#   'W99-0606'],
#  'C02-1102': ['C00-1043',
#   'J93-2003',
#   'J97-3002',
#   'N01-1005',
#   'W01-1204',
#   'W99-0612'],
#  'C02-1103': ['C00-1066', 'W00-0403'],
#  'C02-1104': ['C90-2004', 'P01-1024', 'P01-1045', 'P90-1005'],
#  'C02-1105': ['C92-2117', 'H01-1010', 'H94-1020', 'P00-1065', 'P98-1013'],
#  'C02-1106': ['C96-2122', 'W98-0511'],
#  'C02-1107': ['C02-1136', 'W00-1001', 'W01-1603'],
#  'C02-1108': ['P96-1041', 'P97-1003'],
#  'C02-1109': ['C00-1058', 'P00-1037', 'P98-1003', 'W00-0722', 'W00-0903'],
#  'C02-1110': ['A97-1011', 'C00-1030', 'E99-1043', 'M98-1018'],
#  'C02-1111': [],
#  'C02-1112': ['A00-1031',
#   'J94-4003',
#   'P93-1016',
#   'P94-1013',
#   'P96-1006',
#   'P96-1025',
#   'W98-0701'],
#  'C02-1113': ['E91-1028', 'P01-1024', 'P01-1061', 'P02-1003', 'P98-2204'],
#  'C02-1114': ['J98-1004', 'P98-2127', 'P98-2182', 'W97-0313'],
#  'C02-1115': ['A97-1011', 'N01-1011', 'P01-1027', 'P96-1006', 'W00-0804'],
#  'C02-1116': ['P01-1024', 'P98-1013'],
#  'C02-1117': ['H92-1073', 'W96-0106'],
#  'C02-1118': ['A97-1052',
#   'C00-2100',
#   'C92-2065',
#   'C92-2066',
#   'J93-2002',
#   'P00-1058',
#   'P91-1027',
#   'P93-1032',
#   'P96-1025',
#   'P97-1003',
#   'P98-1071',
#   'P98-1080',
#   'W00-1325',
#   'W00-1327',
#   'W93-0109',
#   'W98-1114'],
#  'C02-1119': ['C02-1053', 'C02-1054', 'J96-1002', 'N01-1025', 'W01-0509'],
#  'C02-1120': ['C00-1043', 'C00-1060', 'J92-4003', 'P99-1014'],
#  'C02-1121': ['A00-1033',
#   'A97-1014',
#   'A97-1031',
#   'C00-2105',
#   'C00-2124',
#   'E99-1016',
#   'W95-0107',
#   'W98-1117'],
#  'C02-1122': ['H01-1043'],
#  'C02-1123': ['C00-2086', 'C00-2161', 'W01-1014', 'W98-0606'],
#  'C02-1124': ['P83-1007', 'P87-1022'],
#  'C02-1125': ['C00-1047', 'J90-1003', 'J93-1003'],
#  'C02-1126': ['A00-2018',
#   'A97-1029',
#   'J93-2004',
#   'J95-4002',
#   'J98-4004',
#   'N01-1023',
#   'P00-1058',
#   'P95-1021',
#   'P95-1037',
#   'P98-1091',
#   'W00-1201',
#   'W97-0301'],
#  'C02-1127': ['A00-1034',
#   'C92-2070',
#   'H92-1045',
#   'J92-1001',
#   'J94-4003',
#   'M98-1015',
#   'P95-1026',
#   'P96-1006'],
#  'C02-1128': ['P98-2173'],
#  'C02-1129': ['W93-0113'],
#  'C02-1130': ['A97-1030', 'C00-1072', 'J93-1003', 'P00-1011', 'W99-0613'],
#  'C02-1131': ['A00-1031',
#   'A00-1033',
#   'A94-1008',
#   'C00-1046',
#   'P01-1035',
#   'P98-1081',
#   'W02-2032'],
#  'C02-1132': ['A00-2031',
#   'A00-2034',
#   'C00-2108',
#   'H94-1020',
#   'J01-2004',
#   'J01-3003',
#   'J94-2001',
#   'P93-1024',
#   'P95-1037',
#   'P97-1003',
#   'P99-1014'],
#  'C02-1133': ['C00-1004'],
#  'C02-1134': ['J93-2003', 'P98-2186', 'P99-1068'],
#  'C02-1135': ['J96-2004', 'P01-1031', 'W00-0302', 'W01-1616', 'W02-0222'],
#  'C02-1136': ['E99-1026'],
#  'C02-1137': ['J90-2002'],
#  'C02-1138': ['A00-2018',
#   'C00-1007',
#   'C00-2126',
#   'J93-2004',
#   'J99-2004',
#   'N01-1003',
#   'P00-1058',
#   'P95-1034',
#   'P98-1116',
#   'P98-1118',
#   'W00-0306',
#   'W00-1401',
#   'W01-0520'],
#  'C02-1139': ['C96-1021',
#   'J00-4005',
#   'J01-4004',
#   'J94-4002',
#   'M95-1005',
#   'N01-1008',
#   'P02-1014',
#   'P95-1017',
#   'P98-1012',
#   'P99-1048'],
#  'C02-1140': ['C00-1050', 'C94-1032', 'C96-2206', 'J98-4003'],
#  'C02-1141': ['W01-0803'],
#  'C02-1142': ['E99-1005',
#   'J90-1003',
#   'J93-1003',
#   'J93-2004',
#   'P01-1043',
#   'W01-0513',
#   'W01-0516'],
#  'C02-1143': ['A97-1029',
#   'J96-1002',
#   'J96-3004',
#   'J98-1001',
#   'P97-1003',
#   'W00-1201',
#   'W02-0813'],
#  'C02-1144': ['C94-1079', 'J98-1006', 'P98-2127', 'P99-1005'],
#  'C02-1145': ['H01-1026', 'P00-1058', 'W00-1207', 'W96-0213'],
#  'C02-1146': ['C00-2108',
#   'H01-1035',
#   'J01-3003',
#   'J94-4003',
#   'J95-4004',
#   'P98-2247',
#   'W01-0705',
#   'W99-0632'],
#  'C02-1147': ['P98-1075', 'W00-0303'],
#  'C02-1148': [],
#  'C02-1149': ['H01-1044'],
#  'C02-1150': ['H01-1069', 'P99-1042', 'W01-0502', 'W01-0706', 'W01-1203'],
#  'C02-1151': ['P99-1042', 'W99-0613', 'W99-0621'],
#  'C02-1152': ['C00-1068', 'C00-1073', 'P96-1009', 'P98-1040'],
#  'C02-1153': ['C92-1034', 'C96-1034', 'P95-1011', 'P98-1033', 'W02-1507'],
#  'C02-1154': ['A97-1029',
#   'C00-2136',
#   'C96-1071',
#   'C96-2157',
#   'C96-2212',
#   'W98-1118',
#   'W99-0612',
#   'W99-0613'],
#  'C02-1155': ['C92-2069'],
#  'C02-1156': ['P00-1065', 'P98-1013'],
#  'C02-1157': ['C00-1081',
#   'J94-4001',
#   'P01-1017',
#   'P92-1017',
#   'P97-1003',
#   'P98-1035',
#   'P98-1083',
#   'W00-1303'],
#  'C02-1158': ['C00-1075', 'C90-3044', 'C96-2178', 'J90-2002', 'P98-2223'],
#  'C02-1159': ['A00-2018', 'A92-1021', 'H01-1046', 'J93-2004'],
#  'C02-1160': ['W01-0504', 'W01-1402', 'W01-1406', 'W01-1411'],
#  'C02-1161': ['A92-1021', 'P01-1037', 'P98-2127', 'P99-1020', 'W98-0705'],
#  'C02-1162': ['J90-2002',
#   'J95-4004',
#   'J96-1001',
#   'N01-1006',
#   'P93-1001',
#   'P95-1050',
#   'P98-1069',
#   'P98-2127',
#   'P99-1004',
#   'W97-0311'],
#  'C02-1163': ['C02-1056'],
#  'C02-1164': ['C00-2123', 'C00-2163', 'H94-1014', 'J93-2003', 'P00-1056'],
#  'C02-1165': ['M95-1014'],
#  'C02-1166': ['C96-2098', 'J93-1003', 'P99-1067'],
#  'C02-1167': ['J91-1002', 'W99-0501'],
#  'C02-1168': ['C92-2070',
#   'C96-1005',
#   'H93-1052',
#   'H93-1061',
#   'J96-1002',
#   'W96-0213',
#   'W97-0209'],
#  'C02-1169': ['C00-1043', 'P01-1037', 'P96-1025', 'P98-1035'],
#  'C02-1170': ['W00-0203'],
#  'C02-2001': [],
#  'C02-2002': ['W00-1207'],
#  'C02-2003': ['J93-1003', 'J93-1007'],
#  'C02-2004': [],
#  'C02-2005': ['J93-1003', 'J97-2002'],
#  'C02-2006': ['C00-2132', 'J80-1003', 'P96-1020'],
#  'C02-2007': [],
#  'C02-2008': [],
#  'C02-2009': ['W01-0802'],
#  'C02-2010': ['P98-2196'],
#  'C02-2011': ['W90-0108', 'W98-1106'],
#  'C02-2012': [],
#  'C02-2013': ['C92-2082', 'W99-0621'],
#  'C02-2014': ['A94-1003', 'A94-1004', 'A94-1046', 'P99-1034'],
#  'C02-2015': ['A97-1020', 'P98-2174', 'P98-2175', 'P99-1034'],
#  'C02-2016': [],
#  'C02-2017': [],
#  'C02-2018': ['A92-1021', 'C96-2187'],
#  'C02-2019': ['C96-2202', 'J96-1002', 'P99-1036', 'W01-0512'],
#  'C02-2020': ['P98-1069', 'P99-1067', 'W97-0119'],
#  'C02-2021': [],
#  'C02-2022': ['C00-2171'],
#  'C02-2023': [],
#  'C02-2024': ['J93-2004', 'P99-1061'],
#  'C02-2025': ['J97-4005',
#   'P01-1019',
#   'P97-1003',
#   'P99-1069',
#   'W02-2030',
#   'W97-1502'],
#  'C02-2026': ['C94-1079', 'J00-1003', 'P97-1003'],
#  'C02-2027': ['H89-1022', 'W96-0411', 'W98-1404'],
#  'C02-2028': ['J87-1004'],
#  'C04-1001': ['A92-1039'],
#  'C04-1002': ['C00-2109',
#   'C00-2110',
#   'C96-1058',
#   'E99-1026',
#   'J94-4001',
#   'P03-1004',
#   'P96-1025',
#   'P98-1083',
#   'W00-1303',
#   'W02-2016',
#   'W97-0301'],
#  'C04-1003': ['J00-1002', 'J97-2003', 'N03-1009'],
#  'C04-1004': ['J93-2004',
#   'J93-2006',
#   'J94-2001',
#   'P02-1060',
#   'W00-1309',
#   'W97-0307',
#   'W97-0811'],
#  'C04-1005': ['J00-2004',
#   'J93-2003',
#   'J97-3002',
#   'P00-1056',
#   'P03-1012',
#   'P98-1004',
#   'W01-1406',
#   'W03-1610'],
#  'C04-1006': ['C96-2141',
#   'J00-2004',
#   'J03-1002',
#   'J93-2003',
#   'J97-3002',
#   'P00-1056',
#   'P03-1011',
#   'P03-1012',
#   'W02-1012'],
#  'C04-1007': ['H91-1060', 'J88-2006', 'J91-1002', 'N03-1030', 'P88-1014'],
#  'C04-1008': ['E95-1035',
#   'P00-1010',
#   'P93-1010',
#   'W01-1305',
#   'W01-1309',
#   'W01-1312',
#   'W01-1314',
#   'W01-1315'],
#  'C04-1009': ['C04-1041',
#   'C86-1045',
#   'P04-1014',
#   'P90-1001',
#   'P96-1011',
#   'W02-1502'],
#  'C04-1010': ['A00-2018',
#   'A00-2031',
#   'C96-1058',
#   'H92-1026',
#   'J03-4001',
#   'J93-2004',
#   'P95-1037',
#   'P96-1025',
# ...
#  'C04-1129': ['A00-1043',
#   'C96-2183',
#   'N03-1020',
#   'N03-1026',
#   'N03-2024',
#   'W03-1101',
#   'W99-0625'],
#  'C04-1130': ['A00-2009',
#   'J98-1001',
#   'P94-1013',
#   'P96-1006',
#   'W02-0811',
#   'W02-1004'],
#  'C04-1131': ['P96-1006',
#   'W02-1006',
#   'W95-0104',
#   'W96-0208',
#   'W96-0210',
#   'W97-0201',
#   'W97-0323'],
#  'C04-1132': ['A00-2009', 'J01-3001', 'P97-1007', 'W02-0807'],
#  'C04-1133': ['A97-1052',
#   'C00-1028',
#   'C02-1112',
#   'C92-2070',
#   'J01-3001',
#   'N01-1013',
#   'P03-1007',
#   'P03-2029',
#   'P95-1026',
#   'P99-1014',
#   'W01-0703',
#   'W97-0808',
#   'W98-0701'],
#  'C04-1134': ['C02-1162',
#   'J02-3001',
#   'J03-2001',
#   'J97-3002',
#   'P98-1013',
#   'W02-2006',
#   'W03-1007',
#   'W96-0213'],
#  'C04-1135': ['C00-1060', 'C92-2082', 'N04-1010', 'P03-1001', 'P99-1016'],
#  'C04-1136': ['C00-2137', 'J93-1003', 'P01-1025'],
#  'C04-1137': ['A00-2038', 'J99-1003'],
#  'C04-1138': [],
#  'C04-1139': ['P04-1026'],
#  'C04-1140': ['A00-1031',
#   'A97-1014',
#   'J93-2004',
#   'J95-4004',
#   'N03-1033',
#   'P97-1032',
#   'W96-0213'],
#  'C04-1141': ['A00-1031',
#   'C96-1097',
#   'J90-1003',
#   'J93-1003',
#   'J93-1007',
#   'P01-1025',
#   'P90-1032',
#   'P98-2127',
#   'P99-1041'],
#  'C04-1142': ['A97-1032', 'C00-1025', 'C00-1049'],
#  'C04-1143': ['A00-1040',
#   'C00-1031',
#   'C86-1061',
#   'E03-2013',
#   'J98-3005',
#   'P98-2143',
#   'W00-0403',
#   'W97-0703',
#   'W97-1307'],
#  'C04-1144': ['J02-4005',
#   'P02-1058',
#   'P99-1071',
#   'W00-0405',
#   'W00-0409',
#   'W02-1907'],
#  'C04-1145': ['C00-1044', 'P02-1053', 'P97-1023', 'W01-1626'],
#  'C04-1146': ['J92-4003',
#   'P98-2127',
#   'P99-1004',
#   'P99-1016',
#   'W02-0908',
#   'W03-1011',
#   'W03-1810',
#   'W03-1812'],
#  'C04-1147': ['C02-1007',
#   'C02-1033',
#   'C02-1065',
#   'C02-1125',
#   'J03-3005',
#   'N03-1032',
#   'P97-1048',
#   'W03-1011'],
#  'C04-1148': [],
#  'C04-1149': ['C02-1011', 'E03-1023', 'P98-1069', 'P99-1067'],
#  'C04-1150': ['J04-2002'],
#  'C04-1151': ['J03-3002',
#   'J93-1004',
#   'J93-1007',
#   'N03-1015',
#   'N04-1034',
#   'N04-4010',
#   'P95-1050',
#   'P98-1069',
#   'P99-1043',
#   'W03-1004',
#   'W97-0119',
#   'W99-0905'],
#  'C04-1152': ['J01-2001', 'W00-0712', 'W02-0602', 'W02-0603', 'W02-0606'],
#  'C04-1153': ['A97-1052', 'C00-2100', 'W00-1325', 'W01-0715'],
#  'C04-1154': ['C00-2092',
#   'C94-2178',
#   'J93-1004',
#   'J93-1006',
#   'P03-1011',
#   'P03-2041',
#   'P93-1004'],
#  'C04-1155': ['C88-1013',
#   'C90-3044',
#   'C92-2101',
#   'P93-1004',
#   'P98-2139',
#   'W02-1601'],
#  'C04-1156': ['J03-1002', 'P00-1055'],
#  'C04-1157': ['A00-2018',
#   'E93-1025',
#   'H94-1020',
#   'J95-4004',
#   'J97-4002',
#   'P02-1018',
#   'W02-2018',
#   'W99-0705'],
#  'C04-1158': ['C00-1068',
#   'C02-1084',
#   'C02-1152',
#   'C02-1169',
#   'J94-4001',
#   'P96-1009'],
#  'C04-1159': ['C02-1136',
#   'E99-1026',
#   'N01-1025',
#   'P96-1025',
#   'P98-1083',
#   'W00-1303'],
#  'C04-1160': ['C02-1156', 'C04-1100', 'W04-2806'],
#  'C04-1161': ['J01-3003',
#   'J96-2004',
#   'N01-1009',
#   'P02-1029',
#   'P93-1023',
#   'P98-1013',
#   'W99-0503'],
#  'C04-1162': ['C90-2067',
#   'C92-1056',
#   'H92-1045',
#   'H93-1052',
#   'H93-1061',
#   'J91-1002',
#   'W97-0209',
#   'W98-0701'],
#  'C04-1163': ['A00-1031', 'P00-1064', 'W02-1304'],
#  'C04-1164': ['P98-1116'],
#  'C04-1165': ['P90-1034', 'P93-1023', 'W00-0110'],
#  'C04-1166': ['C00-1036', 'C90-3048', 'E03-3006', 'P98-2173', 'W99-0625'],
#  'C04-1167': ['J99-2004', 'P01-1017', 'P98-1035', 'W02-1031'],
#  'C04-1168': ['J03-1002',
#   'J93-2003',
#   'P02-1040',
#   'P03-1021',
#   'W02-0706',
#   'W02-1018',
#   'W02-1021'],
#  'C04-1169': ['J00-4005'],
#  'C04-1170': ['W04-0202'],
#  'C04-1171': ['E03-1017',
#   'J02-1003',
#   'J03-1003',
#   'P02-1013',
#   'P99-1017',
#   'W00-1416'],
#  'C04-1172': [],
#  'C04-1173': ['C90-2067', 'C96-1005', 'E93-1028', 'J98-1001', 'W99-0901'],
#  'C04-1174': ['A97-1052',
#   'C02-1122',
#   'C96-1084',
#   'J00-4003',
#   'J94-4001',
#   'J99-3001',
#   'P99-1062',
#   'W99-0206'],
#  'C04-1175': ['J00-3004'],
#  'C04-1176': [],
#  'C04-1177': ['J04-1003', 'P04-1036', 'P98-2127', 'W04-0837'],
#  'C04-1178': ['P98-2182', 'W02-1028', 'W02-2023', 'W97-0313'],
#  'C04-1179': ['E03-1055',
#   'J02-3001',
#   'J96-1002',
#   'N03-2009',
#   'P97-1003',
#   'W03-1007'],
#  'C04-1180': ['A00-2018',
#   'C02-1105',
#   'C04-1041',
#   'N04-1013',
#   'P02-1042',
#   'P02-1043',
#   'P04-1014',
#   'W03-1013'],
#  'C04-1181': ['J03-2002', 'P01-1031', 'P01-1061'],
#  'C04-1182': ['N04-4007'],
#  'C04-1183': ['C02-1002',
#   'E03-1026',
#   'J93-1003',
#   'P00-1050',
#   'P03-1058',
#   'W93-0301'],
#  'C04-1184': ['N03-1003', 'N03-1024', 'P01-1008', 'P02-1040', 'W03-1609'],
#  'C04-1185': ['E03-1052', 'P01-1019', 'P03-1014'],
#  'C04-1186': ['J02-3001',
#   'N03-2008',
#   'N03-2009',
#   'N04-4037',
#   'P02-1031',
#   'P03-1002',
#   'P98-1013',
#   'W03-1006',
#   'W03-1008'],
#  'C04-1187': ['C02-1026', 'P02-1006', 'P02-1054'],
#  'C04-1188': ['C92-2082',
#   'N03-2029',
#   'P02-1006',
#   'P03-1001',
#   'P99-1008',
#   'W02-1111'],
#  'C04-1189': ['C96-2157', 'M98-1007', 'N03-1004'],
#  'C04-1190': ['P03-1004', 'P04-1081', 'W02-0813', 'W02-1002', 'W96-0208'],
#  'C04-1191': ['A00-1024',
#   'A00-1030',
#   'C02-1052',
#   'E03-1009',
#   'J95-4004',
#   'P03-1059'],
#  'C04-1192': ['C02-1002',
#   'J98-1001',
#   'P92-1032',
#   'W02-0808',
#   'W03-0308',
#   'W99-0508'],
#  'C04-1193': ['C02-1052', 'C04-1093', 'P01-1019', 'P97-1007', 'W02-1210'],
#  'C04-1194': ['E03-1020',
#   'J90-1003',
#   'J98-1004',
#   'N03-3004',
#   'W97-0322',
#   'W99-0501'],
#  'C04-1195': ['J03-3005'],
#  'C04-1196': [],
#  'C04-1197': ['C02-1151',
#   'J93-2004',
#   'N04-1030',
#   'P02-1031',
#   'P03-1002',
#   'W00-0726',
#   'W01-0708',
#   'W03-0419',
#   'W03-1006',
#   'W03-1008',
#   'W04-2401',
#   'W04-2416'],
#  'C04-1198': [],
#  'C04-1199': ['A00-1021',
#   'A97-1033',
#   'H01-1006',
#   'H01-1045',
#   'N03-1004',
#   'N03-2029',
#   'N03-2037',
#   'W01-0509',
#   'W03-1209'],
#  'C04-1200': ['P02-1053', 'P97-1023', 'W02-1011', 'W03-0404', 'W03-1017'],
#  'C04-1201': ['C02-1150', 'J03-3001', 'W02-1033', 'W03-1208'],
#  'C04-1202': ['C96-2166', 'P03-1048'],
#  'C04-1203': [],
#  'C04-1204': ['A00-2018',
#   'C88-2121',
#   'H94-1020',
#   'J02-3001',
#   'J96-1002',
#   'J97-4005',
#   'P00-1058',
#   'P02-1031',
#   'P02-1035',
#   'P02-1036',
#   'P02-1042',
#   'P02-1043',
#   'P03-1046',
#   'P98-1013',
#   'P99-1069',
#   'W03-1006',
#   'W03-1008',
#   'W03-1013'],
#  'C08-1001': ['N06-1007',
#   'N06-1008',
#   'N06-1023',
#   'P06-1015',
#   'P06-1079',
#   'P06-1107',
#   'W02-2016',
#   'W04-3206'],
#  'C08-1002': ['C00-2108',
#   'C96-1055',
#   'D07-1125',
#   'H05-1111',
#   'J01-3003',
#   'J04-1003',
#   'J05-1004',
#   'N07-1069',
#   'P05-1022',
#   'P05-3014',
#   'P98-1013',
#   'P98-1046',
#   'P98-1112',
#   'W01-0502',
#   'W04-2606'],
#  'C08-1003': ['H05-1053',
#   'N01-1006',
#   'N01-1011',
#   'P05-1050',
#   'P07-1007',
#   'P07-1033',
#   'W00-1322',
#   'W00-1326',
#   'W04-3237',
#   'W06-1615',
#   'W06-2911',
#   'W07-2016',
#   'W07-2074'],
#  'C08-1004': ['C94-2172', 'P03-1037'],
#  'C08-1005': ['A94-1016',
#   'C02-1076',
#   'D07-1029',
#   'E06-1005',
#   'N03-1017',
#   'N07-1029',
#   'P00-1056',
#   'P03-1021',
#   'P04-1063',
#   'P05-3026'],
#  'C08-1006': ['A92-1021'],
#  'C08-1007': ['J93-2003', 'N03-1017', 'P07-1110'],
#  'C08-1008': ['C04-1080',
#   'D07-1031',
#   'J99-2004',
#   'N06-1041',
#   'P05-1046',
#   'P07-1037',
#   'P07-1094',
#   'P08-1022',
#   'P96-1011',
#   'W06-1620',
#   'W07-0702'],
#  'C08-1009': ['C92-2070',
#   'D07-1107',
#   'P03-1058',
#   'P04-1036',
#   'P05-1049',
#   'P07-1005',
#   'P98-2127',
#   'W02-1006',
#   'W03-1201',
#   'W97-0201',
#   'W97-0703'],
#  'C08-1010': ['N04-3002', 'W04-2307'],
#  'C08-1011': ['P06-1040',
#   'P06-2064',
#   'P07-1112',
#   'W07-2003',
#   'W07-2083',
#   'W96-0309'],
#  'C08-1012': ['A94-1007',
#   'D07-1064',
#   'H05-1105',
#   'J03-4003',
#   'J04-4004',
#   'J93-2004',
#   'J98-1006',
#   'P05-1022',
#   'P07-1031',
#   'P07-1086',
#   'P07-2038',
#   'P92-1003'],
#  'C08-1013': [],
#  'C08-1014': ['C04-1183',
#   'E06-1005',
#   'J00-2004',
#   'J03-1002',
#   'J93-2003',
#   'N03-1017',
#   'N07-1029',
#   'P02-1040',
#   'P03-1021',
#   'P07-1040',
#   'P07-2045'],
#  'C08-1015': ['A00-1031',
#   'D07-1013',
#   'D07-1096',
#   'D07-1111',
#   'D07-1112',
#   'D07-1119',
#   'P06-1043',
#   'P07-1033',
#   'P07-1078',
#   'W06-2932',
#   'W06-2933'],
#  'C08-1016': ['J05-3004', 'W04-0706'],
#  'C08-1017': ['J01-2001',
#   'J92-4003',
#   'N03-1017',
#   'P07-1110',
#   'P98-1108',
#   'W02-0506'],
#  'C08-1018': ['A00-1043',
#   'D07-1008',
#   'E06-1038',
#   'N06-1014',
#   'N07-1023',
#   'P02-1040',
#   'P02-1057',
#   'P03-2041',
#   'P05-1036',
#   'P05-1074',
#   'W03-1101',
#   'W04-3219'],
#  'C08-1019': ['N04-1019', 'N07-1006', 'P05-1018', 'W02-0406', 'W04-1013'],
#  'C08-1020': ['P98-1086', 'W07-1219', 'W08-1002'],
#  'C08-1021': ['C00-1072', 'J98-1006', 'W01-0703', 'W06-1663', 'W07-2015'],
#  'C08-1022': ['N07-2045', 'P06-4020', 'W07-1604', 'W07-1607'],
#  'C08-1023': ['C02-1144',
#   'J04-2002',
#   'N03-1020',
#   'N06-2046',
#   'W00-0403',
#   'W04-1013'],
#  'C08-1024': ['C92-2082',
#   'D07-1114',
#   'E06-1026',
#   'J06-1005',
#   'N04-1010',
#   'N04-1041',
#   'N06-1008',
#   'P02-1053',
#   'P06-1015',
#   'P06-2059',
#   'P99-1008',
#   'W04-3205'],
#  'C08-1025': ['A97-1052',
#   'C04-1024',
#   'J93-1005',
#   'J93-2004',
#   'J98-4004',
#   'N06-1020',
#   'P03-1054',
#   'P05-1022',
#   'P91-1027',
#   'P92-1017',
#   'P93-1032',
#   'P97-1003',
#   'P99-1035',
#   'W01-0521',
#   'W07-2202'],
#  'C08-1026': ['A92-1018',
#   'C04-1080',
#   'E03-1009',
#   'E03-1068',
#   'E95-1020',
#   'J93-2004',
#   'P08-1085',
#   'W96-0102'],
#  'C08-1027': ['A00-2018',
#   'C04-1073',
#   'D07-1077',
#   'N03-1017',
#   'P06-1067',
#   'P07-1091',
#   'W06-3114',
#   'W07-0718'],
#  'C08-1028': ['H05-1079', 'P04-1014', 'W05-1503'],
#  'C08-1029': ['C04-1036',
#   'C04-1051',
#   'J87-3006',
#   'N03-1003',
#   'N07-1071',
#   'P01-1008',
#   'P05-1074',
#   'P07-1010',
#   'P98-2127',
#   'P99-1004',
#   'P99-1044',
#   'W04-3206',
#   'W04-3219',
#   'W05-1202',
#   'W07-1425'],
#  'C08-1030': ['E03-1023',
#   'J03-3002',
#   'J93-1007',
#   'P03-1004',
#   'P04-1067',
#   'P06-1011',
#   'P93-1016',
#   'P98-1041',
#   'W04-3208'],
#  'C08-1031': ['C04-1200',
#   'E06-1025',
#   'P02-1053',
#   'P06-1134',
#   'P97-1023',
#   'W02-1011',
#   'W03-1014',
#   'W06-0302',
#   'W06-1602',
#   'W06-1642',
#   'W07-1018'],
#  'C08-1032': ['C88-2147',
#   'C92-1034',
#   'C96-1034',
#   'E03-1030',
#   'P01-1019',
#   'P06-2032',
#   'P95-1011'],
#  'C08-1033': ['J00-4003',
#   'J01-4004',
#   'P02-1014',
#   'P06-4020',
#   'W02-1040',
#   'W05-1306',
#   'W06-3316',
#   'W06-3328',
#   'W97-1301',
#   'W98-1119'],
#  'C08-1034': ['C02-1130',
#   'C92-2082',
#   'D07-1026',
#   'W02-0816',
#   'W07-2009',
#   'W07-2029'],
#  'C08-1035': [],
#  'C08-1036': ['D07-1061',
#   'J03-3001',
#   'J03-3005',
#   'J06-1003',
#   'P06-1127',
#   'P99-1020',
#   'W05-0603'],
#  'C08-1037': ['J88-2003'],
#  'C08-1038': ['A00-2023',
#   'A00-2026',
#   'C00-1007',
#   'C00-1062',
#   'C96-1045',
#   'D07-1028',
#   'J93-2004',
#   'N07-1021',
#   'P02-1040',
#   'P04-1041',
#   'P06-1130',
#   'W05-1510'],
#  'C08-1039': ['N04-1042', 'P05-1046', 'P07-1036'],
#  'C08-1040': ['C04-1162', 'D07-1069', 'N06-1061', 'W04-3252'],
#  'C08-1041': ['D07-1007',
#   'J96-1002',
#   'N03-1017',
#   'P00-1056',
#   'P02-1038',
#   'P02-1040',
#   'P03-1021',
#   'P05-1033',
#   'P06-1066',
#   'P06-1077',
#   'P06-1121',
#   'P07-1005',
#   'W04-3250',
#   'W05-1506',
#   'W06-3108',
#   'W06-3601'],
#  'C08-1042': ['C04-1052',
#   'D07-1023',
#   'D07-1031',
#   'E03-1009',
#   'E95-1020',
#   'H94-1020',
#   'J06-4002',
#   'J94-2001',
#   'N06-1041',
#   'P02-1017',
#   'P04-1061',
#   'P04-1062',
#   'P05-1044',
#   'P06-1109',
#   'P06-3002',
#   'P07-1049',
#   'P07-1094',
#   'P07-3008'],
#  'C08-1043': [],
#  'C08-1044': [],
#  'C08-1045': ['C92-4203', 'J90-2002'],
#  'C08-1046': ['C04-1002',
#   'C04-1010',
#   'C96-1058',
#   'D07-1064',
#   'D07-1096',
#   'P05-1012',
#   'P05-1013',
#   'P06-1105',
#   'W02-2016',
#   'W06-2901',
#   'W06-2920'],
#  'C08-1047': [],
#  'C08-1048': [],
#  'C08-1049': ['P08-1067', 'P08-1102', 'W02-1001', 'W04-3236', 'W96-0213'],
#  'C08-1050': ['A00-2018',
#   'C04-1010',
#   'C04-1186',
#   'J02-3001',
#   'J93-2004',
#   'N03-1033',
#   'N07-1070',
#   'P02-1031',
#   'P05-1012',
#   'P05-1022',
#   'P05-1072',
#   'P05-1073',
#   'P06-2104',
#   'P83-1010',
#   'P97-1003',
#   'P98-1013',
#   'W03-1008',
#   'W04-0803',
#   'W04-3212',
#   'W05-0620',
#   'W06-2920',
#   'W07-2018'],
#  'C08-1051': ['C02-1120',
#   'C02-1144',
#   'J92-4003',
#   'N03-1032',
#   'N04-1043',
#   'N06-4007',
#   'N07-1043',
#   'P05-1017',
#   'P06-2075',
#   'P08-1047',
#   'P08-1068',
#   'P89-1010',
#   'P90-1034',
#   'P93-1024',
#   'P98-1012',
#   'P98-2124',
#   'P98-2127',
#   'P99-1004',
#   'P99-1014',
#   'W04-3205',
#   'W06-1664'],
#  'C08-1052': ['C04-1071',
#   'D07-1113',
#   'H05-1044',
#   'P02-1053',
#   'P03-1044',
#   'P06-1015',
#   'P06-1134',
#   'P97-1023',
#   'W03-1607',
#   'W06-1642'],
#  'C08-1053': ['C04-1051',
#   'C04-1146',
#   'E06-1051',
#   'H05-1091',
#   'P04-1054',
#   'P06-2111',
#   'P96-1041',
#   'P99-1004',
#   'W05-0637'],
#  'C08-1054': ['C04-1002',
#   'D07-1032',
#   'D07-1063',
#   'D07-1064',
#   'H05-1105',
#   'J94-4001',
#   'P05-1022',
#   'P06-1033',
#   'P06-1053',
#   'P07-1086',
#   'P07-1122',
#   'P92-1003',
#   'P98-2127',
#   'P99-1081',
#   'W02-2016'],
#  'C08-1055': ['J02-1003', 'P04-1052', 'W00-1416', 'W98-1419'],
#  'C08-1056': ['J03-1002',
#   'J90-2002',
#   'P00-1037',
#   'P02-1019',
#   'P06-2005',
#   'P07-2045'],
#  'C08-1057': ['A97-1052', 'C00-2094', 'J06-2001', 'P06-1044', 'W04-3213'],
#  'C08-1058': ['C92-2082',
#   'D07-1034',
#   'P03-2011',
#   'P98-2127',
#   'P99-1016',
#   'W02-0903',
#   'W02-1028',
#   'W04-2103',
#   'W97-0313',
#   'W97-0803'],
#  'C08-1059': ['D07-1051', 'P04-1075', 'P07-1033', 'W03-0419'],
#  'C08-1060': ['D07-1113', 'N03-1033', 'P07-1124', 'W06-2932'],
#  'C08-1061': ['C02-1150', 'H05-1059', 'P05-1045', 'W95-0107'],
#  'C08-1062': ['H05-1115',
#   'N03-1020',
#   'P04-3020',
#   'P06-1047',
#   'W04-3247',
#   'W04-3252'],
#  'C08-1063': ['C04-1200', 'H01-1069', 'P00-1071', 'P02-1058'],
#  'C08-1064': ['D07-1079',
#   'D07-1103',
#   'D07-1104',
#   'H05-1095',
#   'J03-1002',
#   'N03-1017',
#   'N04-4026',
#   'N06-1002',
#   'N06-1013',
#   'N07-1062',
#   'P02-1038',
#   'P02-1040',
#   'P03-1021',
#   'P05-1032',
#   'P06-1002',
#   'P06-1067',
#   'P07-1005',
#   'P07-2045',
#   'W08-0333'],
#  'C08-1065': ['C04-1088', 'P04-1026'],
#  'C08-1066': ['E06-1052',
#   'N06-1006',
#   'P03-1054',
#   'W05-1201',
#   'W06-0705',
#   'W06-3907',
#   'W07-1423',
#   'W07-1431'],
#  'C08-1067': ['J00-2004',
#   'J03-1002',
#   'P02-1050',
#   'P07-2045',
#   'P93-1003',
#   'P98-1074',
#   'W00-0901'],
#  'C08-1068': ['J97-2003',
#   'J98-4003',
#   'P06-1143',
#   'W03-1508',
#   'W04-1613',
#   'W98-1005'],
#  'C08-1069': ['A00-2018',
#   'C04-1041',
#   'J93-2004',
#   'N03-1016',
#   'P03-2041',
#   'P05-1022',
#   'P07-1032',
#   'W05-1511',
#   'W07-2208'],
#  'C08-1070': ['N06-1018', 'N07-1053', 'P00-1010', 'W01-1313', 'W06-0902'],
#  'C08-1071': ['E03-1005',
#   'J05-1003',
#   'J93-2004',
#   'N06-1020',
#   'N07-1070',
#   'P05-1022',
#   'P06-1055',
#   'P07-1078',
#   'P07-1080'],
#  'C08-1072': ['J98-4004',
#   'P03-1054',
#   'P04-1005',
#   'P06-1021',
#   'P08-2027',
#   'P98-1101'],
#  'C08-1073': ['P01-1014', 'W99-0405'],
#  'C08-1074': ['N03-1017', 'P03-1021', 'W04-3250', 'W06-3114'],
#  'C08-1075': ['N06-1060'],
#  'C08-1076': ['P06-2017', 'P07-1014'],
#  'C08-1077': ['W03-1028'],
#  'C08-1078': ['H05-1088', 'P07-2009', 'W04-1017', 'W06-0901'],
#  'C08-1079': ['J01-4004', 'J96-1002', 'P06-1005', 'P07-1107', 'W04-0711'],
#  'C08-1080': ['E03-1041', 'P04-1057', 'P06-1042', 'P98-1014'],
#  'C08-1081': ['C00-2143',
#   'D07-1013',
#   'D07-1096',
#   'E06-1012',
#   'H05-1100',
#   'H92-1026',
#   'P03-1013',
#   'P03-1054',
#   'P03-1055',
#   'P05-1013',
#   'P06-1055',
#   'P06-3009',
#   'P95-1037',
#   'W02-2016',
#   'W06-2920',
#   'W07-2219',
#   'W97-0301'],
#  'C08-1082': ['J05-4002',
#   'J06-3003',
#   'P05-1050',
#   'P06-4020',
#   'P08-1027',
#   'P99-1004',
#   'W07-0730',
#   'W07-1108',
#   'W07-2003'],
#  'C08-1083': ['D07-1064',
#   'J96-1002',
#   'P02-1021',
#   'P02-1038',
#   'P05-1057',
#   'P06-1009',
#   'W01-0516',
#   'W02-0312'],
#  'C08-1084': ['J02-3001',
#   'J02-3004',
#   'J05-1004',
#   'N04-4036',
#   'P03-1068',
#   'P07-1025',
#   'P07-1027',
#   'W03-1007',
#   'W04-3213',
#   'W06-1601',
#   'W06-1617'],
#  'C08-1085': ['H94-1020', 'W00-1205', 'W06-2920'],
#  'C08-1086': ['N07-1013',
#   'P05-1022',
#   'P89-1010',
#   'P93-1016',
#   'P98-2127',
#   'P99-1071'],
#  'C08-1087': ['J02-4002',
#   'N04-1019',
#   'N06-1048',
#   'N06-1061',
#   'N07-1040',
#   'P99-1071',
#   'W06-1613'],
#  'C08-1088': ['D07-1076',
#   'H05-1091',
#   'J03-4003',
#   'P01-1017',
#   'P04-1043',
#   'P04-1054',
#   'P05-1052',
#   'P05-1053',
#   'P06-1104'],
#  'C08-1089': ['P06-1089', 'W00-1207'],
#  ...}
